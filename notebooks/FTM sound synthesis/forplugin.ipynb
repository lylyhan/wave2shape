# %%
import ftm
import numpy as np
import IPython.display as ipd
import matplotlib.pyplot as plt
import time
import ftm_u_shape
import hitdifferentparts

# %%
w11=200 * 2 * np.pi #range 200hz-1200hz
tau11 = 0.5 #range 0.01-0.3
p = 0.23 #how round the sound is, smaller the rougher(metal), range 0-0.3
D = 0 #inharmonicity in smaller values, range 0-10
alpha = 0.1 #range 0-5
sr = 22050

# %% [markdown]
# ## hit different parts with ftm_u_shape

# %%
start_time = time.time()
r1,r2 = (0.5,0.5)
y = ftm_u_shape.getsounds_imp_gaus(10,10,r1,r2,w11,tau11,p,D,alpha,sr,0.4)
print("--- %s seconds ---" % (time.time() - start_time))
imp_time = time.time() - start_time
ipd.Audio(y,rate=sr)
# Out:
# --- 2.1296777725219727 seconds ---
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
start_time = time.time()
r1,r2 = (0.2,0.8)
y = ftm_u_shape.getsounds_imp_gaus(10,10,r1,r2,w11,tau11,p,D,alpha,sr,0.4)
print("--- %s seconds ---" % (time.time() - start_time))
imp_time = time.time() - start_time
ipd.Audio(y,rate=sr)
# Out:
# --- 1.239220142364502 seconds ---
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
start_time = time.time()
r1,r2 = (0.1,0.9)
y = ftm_u_shape.getsounds_imp_gaus(10,10,r1,r2,w11,tau11,p,D,alpha,sr,0.4)
print("--- %s seconds ---" % (time.time() - start_time))
imp_time = time.time() - start_time
ipd.Audio(y,rate=sr)
# Out:
# --- 1.424530029296875 seconds ---
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## hit different parts with hitdiffparts

# %%
start_time = time.time()
r1,r2 = (0.5,0.5)
y = hitdifferentparts.hitdiffparts(r1,r2,w11,tau11,p,D,alpha)
print("--- %s seconds ---" % (time.time() - start_time))
imp_time = time.time() - start_time
ipd.Audio(y,rate=sr)
# Out:
# --- 0.8815622329711914 seconds ---
# --- 0.888916015625 seconds ---
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
start_time = time.time()
r1,r2 = (0.2,0.8)
y = hitdifferentparts.hitdiffparts(r1,r2,w11,tau11,p,D,alpha)
print("--- %s seconds ---" % (time.time() - start_time))
imp_time = time.time() - start_time
ipd.Audio(y,rate=sr)
# Out:
# --- 0.952193021774292 seconds ---
# --- 0.9569120407104492 seconds ---
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
start_time = time.time()
r1,r2 = (0.1,0.9)
y = hitdifferentparts.hitdiffparts(r1,r2,w11,tau11,p,D,alpha)
print("--- %s seconds ---" % (time.time() - start_time))
imp_time = time.time() - start_time
ipd.Audio(y,rate=sr)
# Out:
# --- 0.8865420818328857 seconds ---
# --- 0.8911280632019043 seconds ---
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## gaussian but with G(mu, 0.1) instead of g(mu, 0.4)

# %%
import ftm_u_shape

# %%
start_time = time.time()
r1,r2 = (0.5,0.5)
y = ftm_u_shape.getsounds_imp_gaus(10,10,r1,r2,w11,tau11,p,D,alpha,sr,0.1)
print("--- %s seconds ---" % (time.time() - start_time))
imp_time = time.time() - start_time
ipd.Audio(y,rate=sr)
# Out:
# --- 1.3449528217315674 seconds ---
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
start_time = time.time()
r1,r2 = (0.2,0.8)
y = ftm_u_shape.getsounds_imp_gaus(10,10,r1,r2,w11,tau11,p,D,alpha,sr,0.1)
print("--- %s seconds ---" % (time.time() - start_time))
imp_time = time.time() - start_time
ipd.Audio(y,rate=sr)
# Out:
# --- 1.8250057697296143 seconds ---
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
start_time = time.time()
r1,r2 = (0.1,0.9)
y = ftm_u_shape.getsounds_imp_gaus(10,10,r1,r2,w11,tau11,p,D,alpha,sr,0.1)
print("--- %s seconds ---" % (time.time() - start_time))
imp_time = time.time() - start_time
ipd.Audio(y,rate=sr)
# Out:
# --- 1.6287851333618164 seconds ---
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# getsounds_imp is the impulse implementation
#
# getsounds_dif is the impulse-invariant implementation (difference eq version)

# %%
w11=200 * 2 * np.pi #range 200hz-1200hz
tau11 = 0.2 #range 0.01-0.3
p = 0.23 #how round the sound is, smaller the rougher(metal), range 0-0.3
D = 0 #inharmonicity in smaller values, range 0-10
alpha = 0.1 #range 0-5
sr = 44100
start_time = time.time()
y = ftm.getsounds_imp(10,10,w11,tau11,p*2,D*2,alpha,sr)
print("--- %s seconds ---" % (time.time() - start_time))
imp_time = time.time() - start_time
ipd.Audio(y,rate=sr)
# Out:
# --- 4.07400107383728 seconds ---
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
start_time = time.time()
y_dif = ftm.getsounds_dif(10,10,w11,tau11,p*2,D*2,alpha,sr)
print("--- %s seconds ---" % (time.time() - start_time))
dif_time = time.time() - start_time
ipd.Audio(y_dif,rate=sr)
# Out:
# --- 2.1211061477661133 seconds ---
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
start_time = time.time()
y_bil = ftm.getsounds_bil(10,10,w11,tau11,p*2,D*2,alpha,sr)
print("--- %s seconds ---" % (time.time() - start_time))
bil_time = time.time() - start_time
ipd.Audio(y_bil[1:],rate=sr)
# Out:
# --- 1.9057657718658447 seconds ---
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
imps = []
difs = []
bils = []
for i in range(20):
    start_time = time.time()
    y = ftm.getsounds_imp(10,10,w11,tau11,p*2,D*2,alpha,sr)
    imp_time = time.time() - start_time
    start_time = time.time()
    y_dif = ftm.getsounds_dif(10,10,w11,tau11,p*2,D*2,alpha,sr)
    dif_time = time.time() - start_time
    start_time = time.time()
    y_bil = ftm.getsounds_bil(10,10,w11,tau11,p*2,D*2,alpha,sr)
    bil_time = time.time() - start_time
    imps.append(imp_time)
    difs.append(dif_time)
    bils.append(bil_time)

# %%
plt.boxplot([imps,difs,bils],labels=["discrete time","impulse invarient","bilinear"])
plt.ylabel("Synthesize time (s)")
# Out:
# Text(0, 0.5, 'Synthesize time (s)')

# %%
print(imp_time,dif_time,bil_time)
# Out:
# 1.9646787643432617 2.168026924133301 2.388774871826172

# %%
start_time = time.time()
y_bil2 = ftm.getsounds_bil(10,10,w11,tau11,p*2,D,alpha,sr)
print("--- %s seconds ---" % (time.time() - start_time))
ipd.Audio(y_bil2,rate=sr)
# Out:
# --- 1.9916961193084717 seconds ---
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
w11 = np.array([100,200,300,400,600,800])*2*np.pi
tau = np.array([0.01,0.03,0.1,0.2,0.3])
for t in tau:
    y_bil = ftm.getsounds_bil(10,10,w11[0],t,p*2,D,alpha*0.8,sr)
    print(np.argmax(y_bil),max(y_bil))
# Out:
# 5 5.15102341992946e-08
# 5 6.249654089939531e-08
# 5 6.703553677730696e-08
# 5 6.805924167573732e-08
# 5 6.840456995870839e-08

# %%
w11 = np.array([100,200,300,400,600,800])*2*np.pi
tau = np.array([0.01,0.03,0.1,0.2,0.3])
for w in w11:
    y_bil = ftm.getsounds_bil(10,10,w,tau[0],p*2,D,alpha*0.8,sr)
    print(np.argmax(y_bil),max(y_bil))
# Out:
# 5 5.15102341992946e-08
# 3 2.9071741376357634e-08
# 3 1.9427733421822283e-08
# 2 1.4307026693894316e-08
# 2 9.947956911695964e-09
# 2 7.940879689625518e-09

# %%
np.sum(np.array(y)-np.array(y_dif))
# Out:
# -0.05026846332619477

# %% [markdown]
# problems:
# 1. these synthesis yield really small values, ipd normalizes it automatically, but c++ does not
# 2. impulse implementation is faster than difference implementation, why
# 3. two implementations yield slightly different sounds, dif version is sharper.

# %%
plt.plot(range(len(y)),y)
plt.title('impulse')
plt.figure(2)
plt.plot(range(len(y_dif)),y_dif)
plt.title('difference')
plt.figure(3)
plt.plot(range(len(y_bil)),y_bil/max(y_bil))
plt.title('bilinear')
plt.show()
