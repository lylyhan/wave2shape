# %%
import torch

# %%
from kymatio import Scattering1D
from torch.autograd import backward

learning_rate = 0.1
n_iterations = 100

N = 2**12
scattering = Scattering1D(J=10, shape=(N,))

# Random guess
x = torch.randn((N,), requires_grad=True)
Sx = scattering(x)

# Target
y = torch.randn((N,), requires_grad=False)#was false
Sy = scattering(y)

#with torch.no_grad():
#    x = y.clone()
x.requires_grad = True

print(torch.norm(Sx-Sy))

for it_id in range(n_iterations):
    # Backpropagation
    backward(torch.norm(Sx - Sy))
    delta_x = x.grad
    print(x.grad)

    # Gradient descent
    with torch.no_grad():
        x = x - delta_x * learning_rate
    x.requires_grad = True

    # New forward propagation
    Sx = scattering(x)

    # Measure the new loss
    print(torch.norm(Sx - Sy))
# Out:
# tensor(0.0349, grad_fn=<NormBackward0>)
# tensor([-1.5245e-04, -4.6150e-04, -2.1622e-04,  ..., -4.4550e-05,
#          1.0885e-04, -2.9372e-06])
# tensor(0.0349, grad_fn=<NormBackward0>)
# tensor([-1.5210e-04, -4.6086e-04, -2.1555e-04,  ..., -4.4130e-05,
#          1.0939e-04, -2.6746e-06])
# tensor(0.0348, grad_fn=<NormBackward0>)
# tensor([-1.5175e-04, -4.6022e-04, -2.1487e-04,  ..., -4.3711e-05,
#          1.0993e-04, -2.4116e-06])
# tensor(0.0348, grad_fn=<NormBackward0>)
# tensor([-1.5140e-04, -4.5959e-04, -2.1420e-04,  ..., -4.3292e-05,
#          1.1047e-04, -2.1486e-06])
# tensor(0.0347, grad_fn=<NormBackward0>)
# tensor([-1.5105e-04, -4.5895e-04, -2.1352e-04,  ..., -4.2872e-05,
#          1.1101e-04, -1.8864e-06])
# tensor(0.0347, grad_fn=<NormBackward0>)
# tensor([-1.5069e-04, -4.5831e-04, -2.1285e-04,  ..., -4.2453e-05,
#          1.1155e-04, -1.6228e-06])
# tensor(0.0347, grad_fn=<NormBackward0>)
# tensor([-1.5034e-04, -4.5767e-04, -2.1217e-04,  ..., -4.2033e-05,
#          1.1209e-04, -1.3599e-06])
# tensor(0.0346, grad_fn=<NormBackward0>)
# tensor([-1.4999e-04, -4.5702e-04, -2.1149e-04,  ..., -4.1613e-05,
#          1.1262e-04, -1.0967e-06])
# tensor(0.0346, grad_fn=<NormBackward0>)
# tensor([-1.4964e-04, -4.5638e-04, -2.1081e-04,  ..., -4.1193e-05,
#          1.1316e-04, -8.3344e-07])
# tensor(0.0345, grad_fn=<NormBackward0>)
# tensor([-1.4928e-04, -4.5574e-04, -2.1014e-04,  ..., -4.0773e-05,
#          1.1370e-04, -5.7001e-07])
# tensor(0.0345, grad_fn=<NormBackward0>)
# tensor([-1.4893e-04, -4.5509e-04, -2.0946e-04,  ..., -4.0353e-05,
#          1.1424e-04, -3.0681e-07])
# tensor(0.0345, grad_fn=<NormBackward0>)
# tensor([-1.4857e-04, -4.5444e-04, -2.0878e-04,  ..., -3.9934e-05,
#          1.1478e-04, -4.2790e-08])
# tensor(0.0344, grad_fn=<NormBackward0>)
# tensor([-1.4822e-04, -4.5380e-04, -2.0810e-04,  ..., -3.9514e-05,
#          1.1532e-04,  2.2008e-07])
# tensor(0.0344, grad_fn=<NormBackward0>)
# tensor([-1.4787e-04, -4.5315e-04, -2.0742e-04,  ..., -3.9094e-05,
#          1.1586e-04,  4.8443e-07])
# tensor(0.0343, grad_fn=<NormBackward0>)
# tensor([-1.4751e-04, -4.5250e-04, -2.0674e-04,  ..., -3.8674e-05,
#          1.1639e-04,  7.4736e-07])
# tensor(0.0343, grad_fn=<NormBackward0>)
# tensor([-1.4715e-04, -4.5185e-04, -2.0606e-04,  ..., -3.8254e-05,
#          1.1693e-04,  1.0114e-06])
# tensor(0.0343, grad_fn=<NormBackward0>)
# tensor([-1.4680e-04, -4.5120e-04, -2.0538e-04,  ..., -3.7834e-05,
#          1.1747e-04,  1.2752e-06])
# tensor(0.0342, grad_fn=<NormBackward0>)
# tensor([-1.4644e-04, -4.5055e-04, -2.0470e-04,  ..., -3.7414e-05,
#          1.1801e-04,  1.5389e-06])
# tensor(0.0342, grad_fn=<NormBackward0>)
# tensor([-1.4609e-04, -4.4989e-04, -2.0402e-04,  ..., -3.6994e-05,
#          1.1854e-04,  1.8032e-06])
# tensor(0.0342, grad_fn=<NormBackward0>)
# tensor([-1.4573e-04, -4.4924e-04, -2.0334e-04,  ..., -3.6574e-05,
#          1.1908e-04,  2.0672e-06])
# tensor(0.0341, grad_fn=<NormBackward0>)
# tensor([-1.4537e-04, -4.4859e-04, -2.0266e-04,  ..., -3.6154e-05,
#          1.1962e-04,  2.3309e-06])
# tensor(0.0341, grad_fn=<NormBackward0>)
# tensor([-1.4501e-04, -4.4793e-04, -2.0198e-04,  ..., -3.5735e-05,
#          1.2015e-04,  2.5954e-06])
# tensor(0.0340, grad_fn=<NormBackward0>)
# tensor([-1.4466e-04, -4.4727e-04, -2.0129e-04,  ..., -3.5314e-05,
#          1.2069e-04,  2.8592e-06])
# tensor(0.0340, grad_fn=<NormBackward0>)
# tensor([-1.4430e-04, -4.4661e-04, -2.0061e-04,  ..., -3.4895e-05,
#          1.2122e-04,  3.1234e-06])
# tensor(0.0340, grad_fn=<NormBackward0>)
# tensor([-1.4394e-04, -4.4596e-04, -1.9993e-04,  ..., -3.4475e-05,
#          1.2176e-04,  3.3879e-06])
# tensor(0.0339, grad_fn=<NormBackward0>)
# tensor([-1.4358e-04, -4.4530e-04, -1.9924e-04,  ..., -3.4055e-05,
#          1.2230e-04,  3.6519e-06])
# tensor(0.0339, grad_fn=<NormBackward0>)
# tensor([-1.4322e-04, -4.4464e-04, -1.9856e-04,  ..., -3.3635e-05,
#          1.2283e-04,  3.9162e-06])
# tensor(0.0338, grad_fn=<NormBackward0>)
# tensor([-1.4286e-04, -4.4397e-04, -1.9788e-04,  ..., -3.3215e-05,
#          1.2337e-04,  4.1806e-06])
# tensor(0.0338, grad_fn=<NormBackward0>)
# tensor([-1.4250e-04, -4.4331e-04, -1.9720e-04,  ..., -3.2796e-05,
#          1.2390e-04,  4.4453e-06])
# tensor(0.0338, grad_fn=<NormBackward0>)
# tensor([-1.4214e-04, -4.4265e-04, -1.9651e-04,  ..., -3.2376e-05,
#          1.2444e-04,  4.7095e-06])
# tensor(0.0337, grad_fn=<NormBackward0>)
# tensor([-1.4178e-04, -4.4198e-04, -1.9583e-04,  ..., -3.1956e-05,
#          1.2497e-04,  4.9733e-06])
# tensor(0.0337, grad_fn=<NormBackward0>)
# tensor([-1.4142e-04, -4.4132e-04, -1.9514e-04,  ..., -3.1536e-05,
#          1.2550e-04,  5.2378e-06])
# tensor(0.0337, grad_fn=<NormBackward0>)
# tensor([-1.4106e-04, -4.4065e-04, -1.9446e-04,  ..., -3.1117e-05,
#          1.2604e-04,  5.5024e-06])
# tensor(0.0336, grad_fn=<NormBackward0>)
# tensor([-1.4070e-04, -4.3999e-04, -1.9377e-04,  ..., -3.0697e-05,
#          1.2657e-04,  5.7667e-06])
# tensor(0.0336, grad_fn=<NormBackward0>)
# tensor([-1.4034e-04, -4.3932e-04, -1.9309e-04,  ..., -3.0278e-05,
#          1.2710e-04,  6.0314e-06])
# tensor(0.0336, grad_fn=<NormBackward0>)
# tensor([-1.3998e-04, -4.3865e-04, -1.9240e-04,  ..., -2.9859e-05,
#          1.2764e-04,  6.2957e-06])
# tensor(0.0335, grad_fn=<NormBackward0>)
# tensor([-1.3962e-04, -4.3798e-04, -1.9172e-04,  ..., -2.9439e-05,
#          1.2817e-04,  6.5604e-06])
# tensor(0.0335, grad_fn=<NormBackward0>)
# tensor([-1.3925e-04, -4.3731e-04, -1.9103e-04,  ..., -2.9020e-05,
#          1.2870e-04,  6.8248e-06])
# tensor(0.0334, grad_fn=<NormBackward0>)
# tensor([-1.3889e-04, -4.3664e-04, -1.9034e-04,  ..., -2.8601e-05,
#          1.2923e-04,  7.0896e-06])
# tensor(0.0334, grad_fn=<NormBackward0>)
# tensor([-1.3853e-04, -4.3597e-04, -1.8966e-04,  ..., -2.8182e-05,
#          1.2977e-04,  7.3540e-06])
# tensor(0.0334, grad_fn=<NormBackward0>)
# tensor([-1.3817e-04, -4.3529e-04, -1.8897e-04,  ..., -2.7763e-05,
#          1.3030e-04,  7.6184e-06])
# tensor(0.0333, grad_fn=<NormBackward0>)
# tensor([-1.3780e-04, -4.3462e-04, -1.8828e-04,  ..., -2.7344e-05,
#          1.3083e-04,  7.8832e-06])
# tensor(0.0333, grad_fn=<NormBackward0>)
# tensor([-1.3744e-04, -4.3394e-04, -1.8760e-04,  ..., -2.6925e-05,
#          1.3136e-04,  8.1475e-06])
# tensor(0.0333, grad_fn=<NormBackward0>)
# tensor([-1.3708e-04, -4.3327e-04, -1.8691e-04,  ..., -2.6507e-05,
#          1.3189e-04,  8.4123e-06])
# tensor(0.0332, grad_fn=<NormBackward0>)
# tensor([-1.3671e-04, -4.3259e-04, -1.8622e-04,  ..., -2.6088e-05,
#          1.3242e-04,  8.6764e-06])
# tensor(0.0332, grad_fn=<NormBackward0>)
# tensor([-1.3635e-04, -4.3192e-04, -1.8554e-04,  ..., -2.5670e-05,
#          1.3295e-04,  8.9414e-06])
# tensor(0.0332, grad_fn=<NormBackward0>)
# tensor([-1.3598e-04, -4.3124e-04, -1.8485e-04,  ..., -2.5252e-05,
#          1.3348e-04,  9.2058e-06])
# tensor(0.0331, grad_fn=<NormBackward0>)
# tensor([-1.3562e-04, -4.3056e-04, -1.8416e-04,  ..., -2.4834e-05,
#          1.3401e-04,  9.4703e-06])
# tensor(0.0331, grad_fn=<NormBackward0>)
# tensor([-1.3526e-04, -4.2988e-04, -1.8348e-04,  ..., -2.4416e-05,
#          1.3454e-04,  9.7347e-06])
# tensor(0.0330, grad_fn=<NormBackward0>)
# tensor([-1.3489e-04, -4.2920e-04, -1.8279e-04,  ..., -2.3998e-05,
#          1.3507e-04,  9.9992e-06])
# tensor(0.0330, grad_fn=<NormBackward0>)
# tensor([-1.3452e-04, -4.2852e-04, -1.8210e-04,  ..., -2.3580e-05,
#          1.3559e-04,  1.0263e-05])
# tensor(0.0330, grad_fn=<NormBackward0>)
# tensor([-1.3416e-04, -4.2784e-04, -1.8141e-04,  ..., -2.3162e-05,
#          1.3612e-04,  1.0528e-05])
# tensor(0.0329, grad_fn=<NormBackward0>)
# tensor([-1.3379e-04, -4.2715e-04, -1.8072e-04,  ..., -2.2744e-05,
#          1.3665e-04,  1.0792e-05])
# tensor(0.0329, grad_fn=<NormBackward0>)
# tensor([-1.3343e-04, -4.2647e-04, -1.8004e-04,  ..., -2.2328e-05,
#          1.3717e-04,  1.1057e-05])
# tensor(0.0329, grad_fn=<NormBackward0>)
# tensor([-1.3306e-04, -4.2578e-04, -1.7935e-04,  ..., -2.1910e-05,
#          1.3770e-04,  1.1321e-05])
# tensor(0.0328, grad_fn=<NormBackward0>)
# tensor([-1.3269e-04, -4.2510e-04, -1.7866e-04,  ..., -2.1493e-05,
#          1.3823e-04,  1.1585e-05])
# tensor(0.0328, grad_fn=<NormBackward0>)
# tensor([-1.3233e-04, -4.2441e-04, -1.7797e-04,  ..., -2.1076e-05,
#          1.3875e-04,  1.1849e-05])
# tensor(0.0328, grad_fn=<NormBackward0>)
# tensor([-1.3196e-04, -4.2373e-04, -1.7728e-04,  ..., -2.0659e-05,
#          1.3928e-04,  1.2113e-05])
# tensor(0.0327, grad_fn=<NormBackward0>)
# tensor([-1.3159e-04, -4.2304e-04, -1.7660e-04,  ..., -2.0243e-05,
#          1.3980e-04,  1.2378e-05])
# tensor(0.0327, grad_fn=<NormBackward0>)
# tensor([-1.3123e-04, -4.2235e-04, -1.7591e-04,  ..., -1.9826e-05,
#          1.4033e-04,  1.2642e-05])
# tensor(0.0327, grad_fn=<NormBackward0>)
# tensor([-1.3086e-04, -4.2166e-04, -1.7522e-04,  ..., -1.9411e-05,
#          1.4085e-04,  1.2906e-05])
# tensor(0.0326, grad_fn=<NormBackward0>)
# tensor([-1.3049e-04, -4.2097e-04, -1.7453e-04,  ..., -1.8994e-05,
#          1.4138e-04,  1.3170e-05])
# tensor(0.0326, grad_fn=<NormBackward0>)
# tensor([-1.3012e-04, -4.2028e-04, -1.7384e-04,  ..., -1.8578e-05,
#          1.4190e-04,  1.3434e-05])
# tensor(0.0326, grad_fn=<NormBackward0>)
# tensor([-1.2976e-04, -4.1959e-04, -1.7315e-04,  ..., -1.8163e-05,
#          1.4242e-04,  1.3698e-05])
# tensor(0.0325, grad_fn=<NormBackward0>)
# tensor([-1.2939e-04, -4.1890e-04, -1.7246e-04,  ..., -1.7748e-05,
#          1.4294e-04,  1.3962e-05])
# tensor(0.0325, grad_fn=<NormBackward0>)
# tensor([-1.2902e-04, -4.1821e-04, -1.7178e-04,  ..., -1.7332e-05,
#          1.4346e-04,  1.4225e-05])
# tensor(0.0325, grad_fn=<NormBackward0>)
# tensor([-1.2865e-04, -4.1751e-04, -1.7109e-04,  ..., -1.6917e-05,
#          1.4399e-04,  1.4489e-05])
# tensor(0.0324, grad_fn=<NormBackward0>)
# tensor([-1.2828e-04, -4.1682e-04, -1.7040e-04,  ..., -1.6501e-05,
#          1.4451e-04,  1.4752e-05])
# tensor(0.0324, grad_fn=<NormBackward0>)
# tensor([-1.2791e-04, -4.1613e-04, -1.6971e-04,  ..., -1.6088e-05,
#          1.4503e-04,  1.5016e-05])
# tensor(0.0324, grad_fn=<NormBackward0>)
# tensor([-1.2755e-04, -4.1543e-04, -1.6902e-04,  ..., -1.5673e-05,
#          1.4555e-04,  1.5279e-05])
# tensor(0.0323, grad_fn=<NormBackward0>)
# tensor([-1.2718e-04, -4.1474e-04, -1.6833e-04,  ..., -1.5258e-05,
#          1.4607e-04,  1.5543e-05])
# tensor(0.0323, grad_fn=<NormBackward0>)
# tensor([-1.2681e-04, -4.1404e-04, -1.6764e-04,  ..., -1.4845e-05,
#          1.4659e-04,  1.5806e-05])
# tensor(0.0323, grad_fn=<NormBackward0>)
# tensor([-1.2644e-04, -4.1334e-04, -1.6695e-04,  ..., -1.4431e-05,
#          1.4711e-04,  1.6069e-05])
# tensor(0.0322, grad_fn=<NormBackward0>)
# tensor([-1.2607e-04, -4.1264e-04, -1.6627e-04,  ..., -1.4018e-05,
#          1.4762e-04,  1.6333e-05])
# tensor(0.0322, grad_fn=<NormBackward0>)
# tensor([-1.2570e-04, -4.1195e-04, -1.6558e-04,  ..., -1.3604e-05,
#          1.4814e-04,  1.6596e-05])
# tensor(0.0322, grad_fn=<NormBackward0>)
# tensor([-1.2533e-04, -4.1125e-04, -1.6489e-04,  ..., -1.3191e-05,
#          1.4866e-04,  1.6859e-05])
# tensor(0.0321, grad_fn=<NormBackward0>)
# tensor([-1.2496e-04, -4.1055e-04, -1.6420e-04,  ..., -1.2779e-05,
#          1.4917e-04,  1.7122e-05])
# tensor(0.0321, grad_fn=<NormBackward0>)
# tensor([-1.2459e-04, -4.0985e-04, -1.6351e-04,  ..., -1.2366e-05,
#          1.4969e-04,  1.7385e-05])
# tensor(0.0321, grad_fn=<NormBackward0>)
# tensor([-1.2422e-04, -4.0915e-04, -1.6283e-04,  ..., -1.1954e-05,
#          1.5021e-04,  1.7648e-05])
# tensor(0.0320, grad_fn=<NormBackward0>)
# tensor([-1.2385e-04, -4.0844e-04, -1.6214e-04,  ..., -1.1541e-05,
#          1.5072e-04,  1.7910e-05])
# tensor(0.0320, grad_fn=<NormBackward0>)
# tensor([-1.2348e-04, -4.0774e-04, -1.6145e-04,  ..., -1.1130e-05,
#          1.5124e-04,  1.8173e-05])
# tensor(0.0320, grad_fn=<NormBackward0>)
# tensor([-1.2311e-04, -4.0704e-04, -1.6076e-04,  ..., -1.0718e-05,
#          1.5175e-04,  1.8435e-05])
# tensor(0.0319, grad_fn=<NormBackward0>)
# tensor([-1.2274e-04, -4.0634e-04, -1.6007e-04,  ..., -1.0307e-05,
#          1.5226e-04,  1.8698e-05])
# tensor(0.0319, grad_fn=<NormBackward0>)
# tensor([-1.2236e-04, -4.0563e-04, -1.5938e-04,  ..., -9.8956e-06,
#          1.5278e-04,  1.8960e-05])
# tensor(0.0319, grad_fn=<NormBackward0>)
# tensor([-1.2199e-04, -4.0493e-04, -1.5870e-04,  ..., -9.4850e-06,
#          1.5329e-04,  1.9222e-05])
# tensor(0.0318, grad_fn=<NormBackward0>)
# tensor([-1.2162e-04, -4.0422e-04, -1.5801e-04,  ..., -9.0744e-06,
#          1.5380e-04,  1.9484e-05])
# tensor(0.0318, grad_fn=<NormBackward0>)
# tensor([-1.2125e-04, -4.0352e-04, -1.5732e-04,  ..., -8.6648e-06,
#          1.5431e-04,  1.9746e-05])
# tensor(0.0318, grad_fn=<NormBackward0>)
# tensor([-1.2088e-04, -4.0281e-04, -1.5664e-04,  ..., -8.2546e-06,
#          1.5482e-04,  2.0008e-05])
# tensor(0.0317, grad_fn=<NormBackward0>)
# tensor([-1.2051e-04, -4.0210e-04, -1.5595e-04,  ..., -7.8452e-06,
#          1.5533e-04,  2.0269e-05])
# tensor(0.0317, grad_fn=<NormBackward0>)
# tensor([-1.2014e-04, -4.0140e-04, -1.5526e-04,  ..., -7.4361e-06,
#          1.5584e-04,  2.0531e-05])
# tensor(0.0317, grad_fn=<NormBackward0>)
# tensor([-1.1977e-04, -4.0069e-04, -1.5458e-04,  ..., -7.0271e-06,
#          1.5635e-04,  2.0793e-05])
# tensor(0.0316, grad_fn=<NormBackward0>)
# tensor([-1.1939e-04, -3.9998e-04, -1.5389e-04,  ..., -6.6181e-06,
#          1.5686e-04,  2.1054e-05])
# tensor(0.0316, grad_fn=<NormBackward0>)
# tensor([-1.1902e-04, -3.9927e-04, -1.5320e-04,  ..., -6.2102e-06,
#          1.5737e-04,  2.1315e-05])
# tensor(0.0316, grad_fn=<NormBackward0>)
# tensor([-1.1865e-04, -3.9856e-04, -1.5252e-04,  ..., -5.8021e-06,
#          1.5788e-04,  2.1576e-05])
# tensor(0.0315, grad_fn=<NormBackward0>)
# tensor([-1.1828e-04, -3.9785e-04, -1.5183e-04,  ..., -5.3945e-06,
#          1.5838e-04,  2.1837e-05])
# tensor(0.0315, grad_fn=<NormBackward0>)
# tensor([-1.1791e-04, -3.9714e-04, -1.5114e-04,  ..., -4.9870e-06,
#          1.5889e-04,  2.2097e-05])
# tensor(0.0315, grad_fn=<NormBackward0>)
# tensor([-1.1753e-04, -3.9643e-04, -1.5046e-04,  ..., -4.5803e-06,
#          1.5939e-04,  2.2359e-05])
# tensor(0.0314, grad_fn=<NormBackward0>)
# tensor([-1.1716e-04, -3.9572e-04, -1.4977e-04,  ..., -4.1735e-06,
#          1.5990e-04,  2.2619e-05])
# tensor(0.0314, grad_fn=<NormBackward0>)
# tensor([-1.1679e-04, -3.9501e-04, -1.4909e-04,  ..., -3.7667e-06,
#          1.6040e-04,  2.2879e-05])
# tensor(0.0314, grad_fn=<NormBackward0>)
# tensor([-1.1642e-04, -3.9429e-04, -1.4840e-04,  ..., -3.3608e-06,
#          1.6091e-04,  2.3140e-05])
# tensor(0.0313, grad_fn=<NormBackward0>)

# %%
torch.norm(Sx-Sy)
# Out:
# tensor(0.0266, grad_fn=<NormBackward0>)
