# %%
import hitdifferentparts
import IPython.display as ipd
import numpy as np
sr = 44100
dur = 2**17

# %% [markdown]
# ## (x,y)->sounds
#
# drum info:
#
# $\alpha = 1$
#
# $l = l_2 = \pi$
#
# $\omega_1 = 200Hz$
#
# $\tau_1 = 0.2$
#
# p = 0.3
#
# D = 0
#
# $m_1 = m_2 = 5$

# %%
y1 = hitdifferentparts.hitdiffparts(0.5,0.5)
ipd.Audio(y1,rate=sr)
# Out:
# --- 2.6756937503814697 seconds ---
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Sample from 1/8 th of a drum surface

# %%
x = np.linspace(0,1,20)
y = np.linspace(0,1,20)

# %%
import matplotlib.pyplot as plt

# %%
x_sel = []
y_sel = []
for i in x:
    for j in y:
        if i < 1/2 and j < 1/2:
            if i <= j:
                if i!=0 and j!=0:
                    x_sel.append(i)
                    y_sel.append(j)

# %%
plt.scatter(x_sel,y_sel)
plt.xlim([0,1])
plt.ylim([0,1])
# Out:
# (0, 1)

# %% [markdown]
# ## interpolate sounds from two adjacent points (0.5,0.5) and (0.4,0.5)

# %%
y_1 = hitdifferentparts.hitdiffparts(0.5,0.5)
y_2 = hitdifferentparts.hitdiffparts(0.4,0.5)
# Out:
# --- 3.044110059738159 seconds ---
# --- 2.565945863723755 seconds ---

# %%
ipd.Audio(y_1,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(y_2,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(len(y_1),len(y_2),2**16)
# Out:
# 65536 65536 65536

# %%
import autograd
import torch
from kymatio import Scattering1D

# %%
J = 16
Sy1 = autograd.getsc(torch.Tensor(y_1),J)
Sy2 = autograd.getsc(torch.Tensor(y_2),J)

# %%
Sy_interpolated = (Sy1+Sy2)/2
y_interpolated = autograd.regress_signal(Sy_interpolated,16,0.1,100)
# Out:
# tensor([-3.3810e-05,  1.1177e-05,  1.8263e-04,  ...,  1.3410e-05,
#         -2.4174e-05,  5.3013e-05])
# tensor(4.6966, grad_fn=<NormBackward0>)
# tensor([-3.3810e-05,  1.1177e-05,  1.8263e-04,  ...,  1.3410e-05,
#         -2.4174e-05,  5.3013e-05])
# tensor(4.6965, grad_fn=<NormBackward0>)
# tensor([-3.3810e-05,  1.1177e-05,  1.8263e-04,  ...,  1.3410e-05,
#         -2.4174e-05,  5.3013e-05])
# tensor(4.6965, grad_fn=<NormBackward0>)
# tensor([-3.3810e-05,  1.1177e-05,  1.8263e-04,  ...,  1.3410e-05,
#         -2.4174e-05,  5.3013e-05])
# tensor(4.6965, grad_fn=<NormBackward0>)
# tensor([-3.3810e-05,  1.1177e-05,  1.8263e-04,  ...,  1.3410e-05,
#         -2.4174e-05,  5.3013e-05])
# tensor(4.6964, grad_fn=<NormBackward0>)
# tensor([-3.3810e-05,  1.1177e-05,  1.8263e-04,  ...,  1.3410e-05,
#         -2.4174e-05,  5.3013e-05])
# tensor(4.6964, grad_fn=<NormBackward0>)
# tensor([-3.3810e-05,  1.1177e-05,  1.8263e-04,  ...,  1.3411e-05,
#         -2.4174e-05,  5.3014e-05])
# tensor(4.6963, grad_fn=<NormBackward0>)
# tensor([-3.3810e-05,  1.1177e-05,  1.8263e-04,  ...,  1.3411e-05,
#         -2.4174e-05,  5.3014e-05])
# tensor(4.6963, grad_fn=<NormBackward0>)
# tensor([-3.3810e-05,  1.1177e-05,  1.8263e-04,  ...,  1.3411e-05,
#         -2.4174e-05,  5.3014e-05])
# tensor(4.6963, grad_fn=<NormBackward0>)
# tensor([-3.3810e-05,  1.1177e-05,  1.8263e-04,  ...,  1.3411e-05,
#         -2.4174e-05,  5.3014e-05])
# tensor(4.6962, grad_fn=<NormBackward0>)
# tensor([-3.3810e-05,  1.1176e-05,  1.8263e-04,  ...,  1.3411e-05,
#         -2.4174e-05,  5.3014e-05])
# tensor(4.6962, grad_fn=<NormBackward0>)
# tensor([-3.3810e-05,  1.1176e-05,  1.8263e-04,  ...,  1.3411e-05,
#         -2.4174e-05,  5.3014e-05])
# tensor(4.6961, grad_fn=<NormBackward0>)
# tensor([-3.3809e-05,  1.1176e-05,  1.8263e-04,  ...,  1.3411e-05,
#         -2.4174e-05,  5.3014e-05])
# tensor(4.6961, grad_fn=<NormBackward0>)
# tensor([-3.3809e-05,  1.1176e-05,  1.8263e-04,  ...,  1.3411e-05,
#         -2.4174e-05,  5.3014e-05])
# tensor(4.6960, grad_fn=<NormBackward0>)
# tensor([-3.3809e-05,  1.1176e-05,  1.8263e-04,  ...,  1.3411e-05,
#         -2.4174e-05,  5.3015e-05])
# tensor(4.6960, grad_fn=<NormBackward0>)
# tensor([-3.3809e-05,  1.1176e-05,  1.8263e-04,  ...,  1.3411e-05,
#         -2.4174e-05,  5.3015e-05])
# tensor(4.6960, grad_fn=<NormBackward0>)
# tensor([-3.3809e-05,  1.1176e-05,  1.8263e-04,  ...,  1.3411e-05,
#         -2.4174e-05,  5.3015e-05])
# tensor(4.6959, grad_fn=<NormBackward0>)
# tensor([-3.3809e-05,  1.1176e-05,  1.8263e-04,  ...,  1.3411e-05,
#         -2.4174e-05,  5.3015e-05])
# tensor(4.6959, grad_fn=<NormBackward0>)
# tensor([-3.3809e-05,  1.1176e-05,  1.8263e-04,  ...,  1.3411e-05,
#         -2.4174e-05,  5.3015e-05])
# tensor(4.6958, grad_fn=<NormBackward0>)
# tensor([-3.3809e-05,  1.1176e-05,  1.8262e-04,  ...,  1.3411e-05,
#         -2.4174e-05,  5.3015e-05])
# tensor(4.6958, grad_fn=<NormBackward0>)
# tensor([-3.3809e-05,  1.1176e-05,  1.8262e-04,  ...,  1.3411e-05,
#         -2.4174e-05,  5.3015e-05])
# tensor(4.6958, grad_fn=<NormBackward0>)
# tensor([-3.3809e-05,  1.1176e-05,  1.8262e-04,  ...,  1.3411e-05,
#         -2.4174e-05,  5.3015e-05])
# tensor(4.6957, grad_fn=<NormBackward0>)
# tensor([-3.3809e-05,  1.1176e-05,  1.8262e-04,  ...,  1.3412e-05,
#         -2.4174e-05,  5.3016e-05])
# tensor(4.6957, grad_fn=<NormBackward0>)
# tensor([-3.3809e-05,  1.1176e-05,  1.8262e-04,  ...,  1.3412e-05,
#         -2.4174e-05,  5.3016e-05])
# tensor(4.6956, grad_fn=<NormBackward0>)
# tensor([-3.3809e-05,  1.1176e-05,  1.8262e-04,  ...,  1.3412e-05,
#         -2.4174e-05,  5.3016e-05])
# tensor(4.6956, grad_fn=<NormBackward0>)
# tensor([-3.3808e-05,  1.1176e-05,  1.8262e-04,  ...,  1.3412e-05,
#         -2.4174e-05,  5.3016e-05])
# tensor(4.6955, grad_fn=<NormBackward0>)
# tensor([-3.3808e-05,  1.1176e-05,  1.8262e-04,  ...,  1.3412e-05,
#         -2.4174e-05,  5.3016e-05])
# tensor(4.6955, grad_fn=<NormBackward0>)
# tensor([-3.3808e-05,  1.1176e-05,  1.8262e-04,  ...,  1.3412e-05,
#         -2.4174e-05,  5.3016e-05])
# tensor(4.6955, grad_fn=<NormBackward0>)
# tensor([-3.3808e-05,  1.1176e-05,  1.8262e-04,  ...,  1.3412e-05,
#         -2.4174e-05,  5.3016e-05])
# tensor(4.6954, grad_fn=<NormBackward0>)
# tensor([-3.3808e-05,  1.1176e-05,  1.8262e-04,  ...,  1.3412e-05,
#         -2.4174e-05,  5.3017e-05])
# tensor(4.6954, grad_fn=<NormBackward0>)
# tensor([-3.3808e-05,  1.1175e-05,  1.8262e-04,  ...,  1.3412e-05,
#         -2.4174e-05,  5.3017e-05])
# tensor(4.6953, grad_fn=<NormBackward0>)
# tensor([-3.3808e-05,  1.1175e-05,  1.8262e-04,  ...,  1.3412e-05,
#         -2.4173e-05,  5.3017e-05])
# tensor(4.6953, grad_fn=<NormBackward0>)
# tensor([-3.3808e-05,  1.1175e-05,  1.8262e-04,  ...,  1.3412e-05,
#         -2.4173e-05,  5.3017e-05])
# tensor(4.6952, grad_fn=<NormBackward0>)
# tensor([-3.3808e-05,  1.1175e-05,  1.8262e-04,  ...,  1.3412e-05,
#         -2.4173e-05,  5.3017e-05])
# tensor(4.6952, grad_fn=<NormBackward0>)
# tensor([-3.3808e-05,  1.1175e-05,  1.8262e-04,  ...,  1.3412e-05,
#         -2.4173e-05,  5.3017e-05])
# tensor(4.6952, grad_fn=<NormBackward0>)
# tensor([-3.3808e-05,  1.1175e-05,  1.8262e-04,  ...,  1.3412e-05,
#         -2.4173e-05,  5.3017e-05])
# tensor(4.6951, grad_fn=<NormBackward0>)
# tensor([-3.3808e-05,  1.1175e-05,  1.8262e-04,  ...,  1.3412e-05,
#         -2.4173e-05,  5.3017e-05])
# tensor(4.6951, grad_fn=<NormBackward0>)
# tensor([-3.3808e-05,  1.1175e-05,  1.8262e-04,  ...,  1.3412e-05,
#         -2.4173e-05,  5.3018e-05])
# tensor(4.6950, grad_fn=<NormBackward0>)
# tensor([-3.3808e-05,  1.1175e-05,  1.8262e-04,  ...,  1.3412e-05,
#         -2.4173e-05,  5.3018e-05])
# tensor(4.6950, grad_fn=<NormBackward0>)
# tensor([-3.3807e-05,  1.1175e-05,  1.8262e-04,  ...,  1.3413e-05,
#         -2.4173e-05,  5.3018e-05])
# tensor(4.6950, grad_fn=<NormBackward0>)
# tensor([-3.3807e-05,  1.1175e-05,  1.8262e-04,  ...,  1.3413e-05,
#         -2.4173e-05,  5.3018e-05])
# tensor(4.6949, grad_fn=<NormBackward0>)
# tensor([-3.3807e-05,  1.1175e-05,  1.8262e-04,  ...,  1.3413e-05,
#         -2.4173e-05,  5.3018e-05])
# tensor(4.6949, grad_fn=<NormBackward0>)
# tensor([-3.3807e-05,  1.1175e-05,  1.8262e-04,  ...,  1.3413e-05,
#         -2.4173e-05,  5.3018e-05])
# tensor(4.6948, grad_fn=<NormBackward0>)
# tensor([-3.3807e-05,  1.1175e-05,  1.8262e-04,  ...,  1.3413e-05,
#         -2.4173e-05,  5.3018e-05])
# tensor(4.6948, grad_fn=<NormBackward0>)
# tensor([-3.3807e-05,  1.1175e-05,  1.8262e-04,  ...,  1.3413e-05,
#         -2.4173e-05,  5.3018e-05])
# tensor(4.6947, grad_fn=<NormBackward0>)
# tensor([-3.3807e-05,  1.1175e-05,  1.8262e-04,  ...,  1.3413e-05,
#         -2.4173e-05,  5.3019e-05])
# tensor(4.6947, grad_fn=<NormBackward0>)
# tensor([-3.3807e-05,  1.1175e-05,  1.8262e-04,  ...,  1.3413e-05,
#         -2.4173e-05,  5.3019e-05])
# tensor(4.6947, grad_fn=<NormBackward0>)
# tensor([-3.3807e-05,  1.1175e-05,  1.8262e-04,  ...,  1.3413e-05,
#         -2.4173e-05,  5.3019e-05])
# tensor(4.6946, grad_fn=<NormBackward0>)
# tensor([-3.3807e-05,  1.1175e-05,  1.8262e-04,  ...,  1.3413e-05,
#         -2.4173e-05,  5.3019e-05])
# tensor(4.6946, grad_fn=<NormBackward0>)
# tensor([-3.3807e-05,  1.1175e-05,  1.8262e-04,  ...,  1.3413e-05,
#         -2.4173e-05,  5.3019e-05])
# tensor(4.6945, grad_fn=<NormBackward0>)
# tensor([-3.3807e-05,  1.1175e-05,  1.8262e-04,  ...,  1.3413e-05,
#         -2.4173e-05,  5.3019e-05])
# tensor(4.6945, grad_fn=<NormBackward0>)
# tensor([-3.3807e-05,  1.1174e-05,  1.8262e-04,  ...,  1.3413e-05,
#         -2.4173e-05,  5.3019e-05])
# tensor(4.6945, grad_fn=<NormBackward0>)
# tensor([-3.3807e-05,  1.1174e-05,  1.8262e-04,  ...,  1.3413e-05,
#         -2.4173e-05,  5.3020e-05])
# tensor(4.6944, grad_fn=<NormBackward0>)
# tensor([-3.3806e-05,  1.1174e-05,  1.8262e-04,  ...,  1.3413e-05,
#         -2.4173e-05,  5.3020e-05])
# tensor(4.6944, grad_fn=<NormBackward0>)
# tensor([-3.3806e-05,  1.1174e-05,  1.8262e-04,  ...,  1.3413e-05,
#         -2.4173e-05,  5.3020e-05])
# tensor(4.6943, grad_fn=<NormBackward0>)
# tensor([-3.3806e-05,  1.1174e-05,  1.8262e-04,  ...,  1.3414e-05,
#         -2.4173e-05,  5.3020e-05])
# tensor(4.6943, grad_fn=<NormBackward0>)
# tensor([-3.3806e-05,  1.1174e-05,  1.8262e-04,  ...,  1.3414e-05,
#         -2.4173e-05,  5.3020e-05])
# tensor(4.6942, grad_fn=<NormBackward0>)
# tensor([-3.3806e-05,  1.1174e-05,  1.8262e-04,  ...,  1.3414e-05,
#         -2.4173e-05,  5.3020e-05])
# tensor(4.6942, grad_fn=<NormBackward0>)
# tensor([-3.3806e-05,  1.1174e-05,  1.8262e-04,  ...,  1.3414e-05,
#         -2.4173e-05,  5.3020e-05])
# tensor(4.6942, grad_fn=<NormBackward0>)
# tensor([-3.3806e-05,  1.1174e-05,  1.8262e-04,  ...,  1.3414e-05,
#         -2.4173e-05,  5.3020e-05])
# tensor(4.6941, grad_fn=<NormBackward0>)
# tensor([-3.3806e-05,  1.1174e-05,  1.8262e-04,  ...,  1.3414e-05,
#         -2.4173e-05,  5.3021e-05])
# tensor(4.6941, grad_fn=<NormBackward0>)
# tensor([-3.3806e-05,  1.1174e-05,  1.8262e-04,  ...,  1.3414e-05,
#         -2.4173e-05,  5.3021e-05])
# tensor(4.6940, grad_fn=<NormBackward0>)
# tensor([-3.3806e-05,  1.1174e-05,  1.8262e-04,  ...,  1.3414e-05,
#         -2.4173e-05,  5.3021e-05])
# tensor(4.6940, grad_fn=<NormBackward0>)
# tensor([-3.3806e-05,  1.1174e-05,  1.8262e-04,  ...,  1.3414e-05,
#         -2.4173e-05,  5.3021e-05])
# tensor(4.6940, grad_fn=<NormBackward0>)
# tensor([-3.3806e-05,  1.1174e-05,  1.8262e-04,  ...,  1.3414e-05,
#         -2.4173e-05,  5.3021e-05])
# tensor(4.6939, grad_fn=<NormBackward0>)
# tensor([-3.3806e-05,  1.1174e-05,  1.8262e-04,  ...,  1.3414e-05,
#         -2.4173e-05,  5.3021e-05])
# tensor(4.6939, grad_fn=<NormBackward0>)
# tensor([-3.3805e-05,  1.1174e-05,  1.8262e-04,  ...,  1.3414e-05,
#         -2.4173e-05,  5.3021e-05])
# tensor(4.6938, grad_fn=<NormBackward0>)
# tensor([-3.3805e-05,  1.1174e-05,  1.8262e-04,  ...,  1.3414e-05,
#         -2.4173e-05,  5.3021e-05])
# tensor(4.6938, grad_fn=<NormBackward0>)
# tensor([-3.3805e-05,  1.1174e-05,  1.8262e-04,  ...,  1.3414e-05,
#         -2.4173e-05,  5.3022e-05])
# tensor(4.6937, grad_fn=<NormBackward0>)
# tensor([-3.3805e-05,  1.1174e-05,  1.8262e-04,  ...,  1.3414e-05,
#         -2.4173e-05,  5.3022e-05])
# tensor(4.6937, grad_fn=<NormBackward0>)
# tensor([-3.3805e-05,  1.1174e-05,  1.8261e-04,  ...,  1.3414e-05,
#         -2.4172e-05,  5.3022e-05])
# tensor(4.6937, grad_fn=<NormBackward0>)
# tensor([-3.3805e-05,  1.1174e-05,  1.8261e-04,  ...,  1.3415e-05,
#         -2.4172e-05,  5.3022e-05])
# tensor(4.6936, grad_fn=<NormBackward0>)
# tensor([-3.3805e-05,  1.1173e-05,  1.8261e-04,  ...,  1.3415e-05,
#         -2.4172e-05,  5.3022e-05])
# tensor(4.6936, grad_fn=<NormBackward0>)
# tensor([-3.3805e-05,  1.1173e-05,  1.8261e-04,  ...,  1.3415e-05,
#         -2.4172e-05,  5.3022e-05])
# tensor(4.6935, grad_fn=<NormBackward0>)
# tensor([-3.3805e-05,  1.1173e-05,  1.8261e-04,  ...,  1.3415e-05,
#         -2.4172e-05,  5.3022e-05])
# tensor(4.6935, grad_fn=<NormBackward0>)
# tensor([-3.3805e-05,  1.1173e-05,  1.8261e-04,  ...,  1.3415e-05,
#         -2.4172e-05,  5.3023e-05])
# tensor(4.6934, grad_fn=<NormBackward0>)
# tensor([-3.3805e-05,  1.1173e-05,  1.8261e-04,  ...,  1.3415e-05,
#         -2.4172e-05,  5.3023e-05])
# tensor(4.6934, grad_fn=<NormBackward0>)
# tensor([-3.3805e-05,  1.1173e-05,  1.8261e-04,  ...,  1.3415e-05,
#         -2.4172e-05,  5.3023e-05])
# tensor(4.6934, grad_fn=<NormBackward0>)
# tensor([-3.3805e-05,  1.1173e-05,  1.8261e-04,  ...,  1.3415e-05,
#         -2.4172e-05,  5.3023e-05])
# tensor(4.6933, grad_fn=<NormBackward0>)
# tensor([-3.3805e-05,  1.1173e-05,  1.8261e-04,  ...,  1.3415e-05,
#         -2.4172e-05,  5.3023e-05])
# tensor(4.6933, grad_fn=<NormBackward0>)
# tensor([-3.3804e-05,  1.1173e-05,  1.8261e-04,  ...,  1.3415e-05,
#         -2.4172e-05,  5.3023e-05])
# tensor(4.6932, grad_fn=<NormBackward0>)
# tensor([-3.3804e-05,  1.1173e-05,  1.8261e-04,  ...,  1.3415e-05,
#         -2.4172e-05,  5.3023e-05])
# tensor(4.6932, grad_fn=<NormBackward0>)
# tensor([-3.3804e-05,  1.1173e-05,  1.8261e-04,  ...,  1.3415e-05,
#         -2.4172e-05,  5.3023e-05])
# tensor(4.6932, grad_fn=<NormBackward0>)
# tensor([-3.3804e-05,  1.1173e-05,  1.8261e-04,  ...,  1.3415e-05,
#         -2.4172e-05,  5.3024e-05])
# tensor(4.6931, grad_fn=<NormBackward0>)
# tensor([-3.3804e-05,  1.1173e-05,  1.8261e-04,  ...,  1.3415e-05,
#         -2.4172e-05,  5.3024e-05])
# tensor(4.6931, grad_fn=<NormBackward0>)
# tensor([-3.3804e-05,  1.1173e-05,  1.8261e-04,  ...,  1.3415e-05,
#         -2.4172e-05,  5.3024e-05])
# tensor(4.6930, grad_fn=<NormBackward0>)
# tensor([-3.3804e-05,  1.1173e-05,  1.8261e-04,  ...,  1.3415e-05,
#         -2.4172e-05,  5.3024e-05])
# tensor(4.6930, grad_fn=<NormBackward0>)
# tensor([-3.3804e-05,  1.1173e-05,  1.8261e-04,  ...,  1.3415e-05,
#         -2.4172e-05,  5.3024e-05])
# tensor(4.6929, grad_fn=<NormBackward0>)
# tensor([-3.3804e-05,  1.1173e-05,  1.8261e-04,  ...,  1.3416e-05,
#         -2.4172e-05,  5.3024e-05])
# tensor(4.6929, grad_fn=<NormBackward0>)
# tensor([-3.3804e-05,  1.1173e-05,  1.8261e-04,  ...,  1.3416e-05,
#         -2.4172e-05,  5.3024e-05])
# tensor(4.6929, grad_fn=<NormBackward0>)
# tensor([-3.3804e-05,  1.1173e-05,  1.8261e-04,  ...,  1.3416e-05,
#         -2.4172e-05,  5.3024e-05])
# tensor(4.6928, grad_fn=<NormBackward0>)
# tensor([-3.3804e-05,  1.1173e-05,  1.8261e-04,  ...,  1.3416e-05,
#         -2.4172e-05,  5.3025e-05])
# tensor(4.6928, grad_fn=<NormBackward0>)
# tensor([-3.3804e-05,  1.1173e-05,  1.8261e-04,  ...,  1.3416e-05,
#         -2.4172e-05,  5.3025e-05])
# tensor(4.6927, grad_fn=<NormBackward0>)
# tensor([-3.3803e-05,  1.1172e-05,  1.8261e-04,  ...,  1.3416e-05,
#         -2.4172e-05,  5.3025e-05])
# tensor(4.6927, grad_fn=<NormBackward0>)
# tensor([-3.3803e-05,  1.1172e-05,  1.8261e-04,  ...,  1.3416e-05,
#         -2.4172e-05,  5.3025e-05])
# tensor(4.6927, grad_fn=<NormBackward0>)
# tensor([-3.3803e-05,  1.1172e-05,  1.8261e-04,  ...,  1.3416e-05,
#         -2.4172e-05,  5.3025e-05])
# tensor(4.6926, grad_fn=<NormBackward0>)
# tensor([-3.3803e-05,  1.1172e-05,  1.8261e-04,  ...,  1.3416e-05,
#         -2.4172e-05,  5.3025e-05])
# tensor(4.6926, grad_fn=<NormBackward0>)
# tensor([-3.3803e-05,  1.1172e-05,  1.8261e-04,  ...,  1.3416e-05,
#         -2.4172e-05,  5.3025e-05])
# tensor(4.6925, grad_fn=<NormBackward0>)
# tensor([-3.3803e-05,  1.1172e-05,  1.8261e-04,  ...,  1.3416e-05,
#         -2.4172e-05,  5.3025e-05])
# tensor(4.6925, grad_fn=<NormBackward0>)
# tensor([-3.3803e-05,  1.1172e-05,  1.8261e-04,  ...,  1.3416e-05,
#         -2.4172e-05,  5.3026e-05])
# tensor(4.6924, grad_fn=<NormBackward0>)

# %%
import torch
from kymatio import Scattering1D
from torch.autograd import backward
import matplotlib.pyplot as plt

def regress_signal(s_c, j, learning_rate=100, n_iterations=100):
	"""
	this function finds time-domain signal from scattering transform
	input: scattering tranform tensor, length of the signal(implicitly), learning rate and number of iterations
	output: time-domain signal represented in a tensor
	"""

	N = 2**j
	scattering = Scattering1D(J = 4,shape=(N,))

	#random guess
	x = torch.randn((N,),requires_grad=True)
	Sx = scattering(x)
	#target
	Sy = s_c
	history = []
	#x.requires_grad = True
	#n_iterations = 100
	#iterate to regress random guess to be close to target
	for it_id in range(100):
	    # Backpropagation
	    backward(torch.norm(Sx - Sy))
	    delta_x = x.grad
	    #print(x.grad)

	    # Gradient descent
	    with torch.no_grad():
	        x = x - delta_x * learning_rate
	    x.requires_grad = True

	    # New forward propagation
	    Sx = scattering(x)
	    # Measure the new loss
	    history.append(float(torch.norm(Sx-Sy)))
	    #print(torch.norm(Sx - Sy))
        
	#plt.plot(history)
	#plt.show()
	
	return x,history

# %% [markdown]
# verify if the regression actually works - no it doesn't

# %%
y_interpolated,history = regress_signal(Sy_interpolated,16,200,300)
plt.plot(history)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-113-c0aa78be7d28> in <module>
# ----> 1 y_interpolated,history = regress_signal(Sy_interpolated,16,200,300)
#       2 plt.plot(history)
#
# <ipython-input-111-6a9e5110db86> in regress_signal(s_c, j, learning_rate, n_iterations)
#      25         for it_id in range(100):
#      26             # Backpropagation
# ---> 27             backward(torch.norm(Sx - Sy))
#      28             delta_x = x.grad
#      29             #print(x.grad)
#
# RuntimeError: The size of tensor a (4096) must match the size of tensor b (64) at non-singleton dimension 1

# %%
print(history[-1])
ipd.Audio(list(y_interpolated),rate=sr)
# Out:
# 0.09880844503641129
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Sy2.shape
# Out:
# torch.Size([64, 64])

# %%
distance = np.linalg.norm(Sy1-Sy2)
Sy_mid = Sy1-distance

# %%
print(np.linalg.norm(Sy_mid-Sy_interpolated))
# Out:
# 0.58822775

# %%
plt.figure(2)
legend = []
for rate in [100,150,200]:
    y_interpolated,history = regress_signal(Sy_interpolated,16,rate,100)
    legend.append(str(rate))
    plt.plot(history)
plt.legend(legend)

# %%
plt.figure(2)
legend = []
for rate in [200,220,250]:
    y_interpolated,history = regress_signal(Sy_interpolated,16,rate,100)
    legend.append(str(rate))
    plt.plot(history)
plt.legend(legend)

# %%
plt.figure(2)
legend = []
for rate in [220,230,235]:
    y_interpolated,history = regress_signal(Sy_interpolated,16,rate,100)
    legend.append(str(rate))
    plt.plot(history)
plt.legend(legend)

# %% [markdown]
# decided on learning rate being 230

# %%
y_interpolated,history = regress_signal(Sy_interpolated,16,230,300)

# %%
history[-1]
# Out:
# 0.0758727416396141

# %%
y_interpolated2,history = regress_signal(Sy_mid,16,800,100)
history[-1]
# Out:
# 0.602475106716156

# %%
plt.plot(history)

# %%
ipd.Audio(list(y_interpolated2),rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y_inter = np.array(list(y_interpolated))

# %%
print(y_inter,len(y_inter))
ipd.Audio(y_inter,rate=sr)
# Out:
# [tensor(-0.1541, grad_fn=<SelectBackward>)
#  tensor(-0.1366, grad_fn=<SelectBackward>)
#  tensor(-0.1363, grad_fn=<SelectBackward>) ...
#  tensor(-0.1512, grad_fn=<SelectBackward>)
#  tensor(-0.1429, grad_fn=<SelectBackward>)
#  tensor(-0.1450, grad_fn=<SelectBackward>)] 65536
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ground truth sound at (0.45,0.5)

# %%
y_gt = hitdifferentparts.hitdiffparts(0.45,0.5)
ipd.Audio(y_gt,rate=sr)
# Out:
# --- 1.8833122253417969 seconds ---
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(y_gt)

# %%
plt.plot(y_inter)

# %% [markdown]
# ## Kymatio

# %%
import torch
from kymatio import Scattering1D

# %%
# Set the parameters of the scattering transform.
J = 6
T = 2**13
Q = 8

# Generate a sample signal.
x = torch.randn(1, 1, T)

# Define a Scattering1D object.
S = Scattering1D(J, T, Q)

# Calculate the scattering transform.
Sx = S.forward(x)

# %%
print(Sx,Sx.shape)
# Out:
# tensor([[[[-6.2078e-02, -5.3912e-02, -3.8472e-02,  ...,  1.0951e-01,
#             1.2154e-01,  1.1615e-01],
#           [ 1.6576e-01,  1.6780e-01,  1.7115e-01,  ...,  1.6913e-01,
#             1.6445e-01,  1.6491e-01],
#           [ 1.3826e-01,  1.3922e-01,  1.4269e-01,  ...,  1.4335e-01,
#             1.2972e-01,  1.2100e-01],
#           ...,
#           [ 1.7812e-05,  1.9328e-05,  2.4117e-05,  ...,  1.7512e-05,
#             1.7597e-05,  1.6978e-05],
#           [ 2.7673e-05,  2.8760e-05,  3.0415e-05,  ...,  2.0723e-05,
#             2.1456e-05,  2.2471e-05],
#           [ 6.2213e-06,  7.0801e-06,  9.3679e-06,  ...,  3.5884e-05,
#             3.4487e-05,  3.2453e-05]]]]) torch.Size([1, 1, 126, 128])

# %% [markdown]
# ## Kymatio

# %%
import torch
from kymatio import Scattering1D
from kymatio.scattering1d.filter_bank import scattering_filter_factory

# %%
T = len(y1)
np.log2(T)
# Out:
# 16.428491035332247

# %% [markdown]
# example filterbank

# %%
# Set the parameters of the scattering transform.
J = 6 #largest filter would cover 2**6 in time (window size?)
T = 2**13 #signal length
#T = len(y1)
Q = 8 #usually between 4 and 16, filterbank divides the octave in Q parts


phi_f, psi1_f, psi2_f, _ = scattering_filter_factory(np.log2(T), J, Q)

# %%
plt.figure()
plt.plot(np.arange(T)/T, phi_f[0], 'r')

for psi_f in psi1_f:
    plt.plot(np.arange(T)/T, psi_f[0], 'b')

plt.xlim(0, 0.5)

plt.xlabel(r'$\omega$', fontsize=18)
plt.ylabel(r'$\hat\psi_j(\omega)$', fontsize=18)
plt.title('First-order filters (Q = {})'.format(Q), fontsize=18)
# Out:
# Text(0.5, 1.0, 'First-order filters (Q = 8)')

# %% [markdown]
# convert generated signal to torch tensor before carrying out scattering trasform

# %%
# Generate a sample signal.
x = torch.from_numpy(y1).float()
x /= x.abs().max()
x = x.view(1, -1)
# Set scattering transform parameters
T = x.shape[-1]
J = 6
Q = 16
# Define a Scattering1D object.
S = Scattering1D(J, T, Q)

# Calculate the scattering transform.
Sx = S.forward(x)

# %%
meta = Scattering1D.compute_meta_scattering(J, Q)
order0 = (meta['order'] == 0)
order1 = (meta['order'] == 1)
order2 = (meta['order'] == 2)
print(order0,order1,order2)
# Out:
# tensor([ True, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False]) tensor([False,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False]) tensor([False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True])

# %%
plt.figure(figsize=(8, 2))
plt.plot(x[0,:].numpy())
plt.title('Original signal')
# Out:
# Text(0.5, 1.0, 'Original signal')

# %%
plt.figure(figsize=(8, 2))
plt.plot(Sx[0,order0,:].numpy().ravel())
plt.title('Scattering Order 0')
# Out:
# Text(0.5, 1.0, 'Scattering Order 0')

# %%
plt.figure(figsize=(8, 2))
plt.imshow(Sx[0,order1,:].numpy(), aspect='auto')
plt.title('Scattering Order 1')
# Out:
# Text(0.5, 1.0, 'Scattering Order 1')

# %%
plt.figure(figsize=(8, 2))
plt.imshow(Sx[0,order2,:].numpy(), aspect='auto')
plt.title('Scattering Order 2')
# Out:
# Text(0.5, 1.0, 'Scattering Order 2')

# %% [markdown]
# ## reconstruct signals from scattering coefficients
