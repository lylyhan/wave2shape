# %%
1
# Out:
# 1

# %%
import numpy as np
import tensorflow.keras
from tensorflow import keras
import torch
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv1D, AveragePooling1D, Conv2D, MaxPooling2D,ReLU
import tensorflow.keras.backend as K
from tensorflow.keras.models import load_model #save and load models
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, CSVLogger, ModelCheckpoint
import IPython.display as ipd
from kymatio import Scattering1D
import hitdifferentparts
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import pescador
import random
import os
import librosa
import pickle

# %%
# open J-8,Q=1,O=2 pkl file
J = 8
Q = 1
order = 2
pkl_path = '/scratch/hh2263/drum_data/pkl_data/scattering_J-08_Q-01_order2.pkl'
pkl_file = open(pkl_path, 'rb')
Sy_train,y_train = pickle.load(pkl_file) 

pkl_path_val = '/scratch/hh2263/drum_data/val/J_8_Q_1_order_2.pkl'
pkl_val = open(pkl_path_val,'rb')
Sy_val,y_val = pickle.load(pkl_val)
Sy_val = Sy_val.reshape((Sy_val.shape[2],Sy_val.shape[0],Sy_val.shape[1]))

# %%
input_x = Sy_train.shape[1]
input_y = Sy_train.shape[2]
print(Sy_train.shape,Sy_val.shape,y_train.shape,y_val.shape,input_x,input_y)

# %%
df_train = pd.read_csv("./train_param.csv")
df_test = pd.read_csv("./test_param.csv")
df_val = pd.read_csv("./val_param.csv")
df_full = pd.read_csv("./diffshapes_param.csv")

# normalization of the physical parameters
params = df_train.values[:,1:-1]
scaler = MinMaxScaler()
scaler.fit(params)

#normalize training and validation set
y_train_normalized = scaler.transform(y_train)
y_val_normalized = scaler.transform(y_val)

# %%
#make the model
def create_model(J,Q,order,input_x,input_y,k_size,layer_size,nchan_out):
    #fname = random.choice(os.listdir(path_to_train))
    #rand_audio = os.path.join(path_to_train,fname)
    #y,sr = librosa.load(rand_audio)
    #N = len(y)
    #scattering = Scattering1D(J = J,shape=(N,), Q = Q, max_order=order)
    
    #Sy = getsc_new(torch.Tensor(y),J,Q,order,scattering).T
    #nrow, ncol = Sy.shape 
    nrow = input_x
    ncol = input_y
    #naudio = batch_size         # number of images in batch
    nchan_in = 1       # number of input channels.  1 since it is BW
    #input_shape = (nrow,ncol,nchan_in)  # input shape of 1 image
    input_shape = (input_x,input_y)#Sy.shape
    #batch_shape = (naudio,nrow,ncol,nchan_in)  # shape of image batch
    #x = Sy.reshape(batch_shape)
    kernel_size = (k_size,)
    #nchan_out = 16

    K.clear_session()
    model=Sequential()
    #1 conv layer +  1 batch normalization + nonlinear activation + pooling
    model.add(Conv1D(input_shape=input_shape, filters=nchan_out,
                     kernel_size=kernel_size, padding="same",name='conv1'))
    model.add(BatchNormalization())
    model.add(Activation("relu"))
    model.add(AveragePooling1D(pool_size=(4,)))
    
   #second time
    model.add(Conv1D(filters=nchan_out,
                     kernel_size=kernel_size, padding="same",name='conv2' ))
    model.add(BatchNormalization())
    model.add(Activation("relu"))
    model.add(AveragePooling1D(pool_size=(4,)))
    
    #third time
    if layer_size>=3:
        model.add(Conv1D(filters=nchan_out,
                         kernel_size=kernel_size, padding="same",name='conv3' ))
        model.add(BatchNormalization())
        model.add(Activation("relu"))
        model.add(AveragePooling1D(pool_size=(4,)))
        if layer_size==4:
        #fourth time
            model.add(Conv1D(filters=nchan_out,
                             kernel_size=kernel_size, padding="same",name='conv4' ))
            model.add(BatchNormalization())
            model.add(Activation("relu"))
            model.add(AveragePooling1D(pool_size=(2,)))
            if layer_size ==5:
                model.add(Conv1D(filters=nchan_out,
                             kernel_size=kernel_size, padding="same",name='conv5' ))
                model.add(BatchNormalization())
                model.add(Activation("relu"))
                model.add(AveragePooling1D(pool_size=(2,)))

    model.add(BatchNormalization())
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(BatchNormalization())
    #what activation should be chosen for last layer, for regression problem? should be a linear function
    model.add(Dense(5, activation='linear')) #output layer that corresponds to the 5 physical parameters.


    # Compile the model
    model.compile(loss='mse', optimizer='adam', metrics=['mse'])
    
    #print(model.summary())
    return model

# %%
model=create_model(J,Q,order,input_x,input_y,k_size=4,layer_size=4,nchan_out=8)

# %% [markdown]
# ## stick with batch size 32+steps_per_epoch 10
# find different model architecture
# 1. k_size
# 2. layer_size
# 3. nchan_out

# %%
#divide the training up to 1/8, use batch size of 64
k = [4,8,16]
layer = [3,4,5]
nout = [8,16]
n = Sy_train.shape[0]
steps_per_epoch = 10
bs = 32
m = bs*steps_per_epoch
idx = np.arange(0,n,1)
record = []
for k_s in k:
    for lay in layer:
        for no in nout:
            val_loss=[]
            loss=[]
            model=create_model(J,Q,order,input_x,input_y,k_size=k_s,layer_size=lay,nchan_out=no)
            for epoch in range(30):
                np.random.shuffle(idx)
                Sy_temp = Sy_train[idx[:m],:,:]
                y_temp = y_train_normalized[idx[:m],:]
                hist = model.fit(Sy_temp,
                            y_temp,
                            epochs=1,
                            verbose=2,
                            batch_size=bs,
                            validation_data = (Sy_val,y_val_normalized),
                            use_multiprocessing=True)
                loss.append(hist.history['loss'])
                val_loss.append(hist.history['val_loss'])
            record.append((k_s,lay,no,min(loss),min(val_loss),np.where(np.array(val_loss)==min(val_loss))))
# Out:
# Train on 320 samples, validate on 7776 samples
# 320/320 - 10s - loss: 1.0108 - mean_squared_error: 1.0108 - val_loss: 0.1340 - val_mean_squared_error: 0.1340
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.4481 - mean_squared_error: 0.4481 - val_loss: 0.1047 - val_mean_squared_error: 0.1047
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.2860 - mean_squared_error: 0.2860 - val_loss: 0.0856 - val_mean_squared_error: 0.0856
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.2000 - mean_squared_error: 0.2000 - val_loss: 0.0710 - val_mean_squared_error: 0.0710
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1742 - mean_squared_error: 0.1742 - val_loss: 0.0581 - val_mean_squared_error: 0.0581
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1428 - mean_squared_error: 0.1428 - val_loss: 0.0476 - val_mean_squared_error: 0.0476
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1108 - mean_squared_error: 0.1108 - val_loss: 0.0408 - val_mean_squared_error: 0.0408
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0960 - mean_squared_error: 0.0960 - val_loss: 0.0377 - val_mean_squared_error: 0.0377
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0956 - mean_squared_error: 0.0956 - val_loss: 0.0372 - val_mean_squared_error: 0.0372
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0700 - mean_squared_error: 0.0700 - val_loss: 0.0382 - val_mean_squared_error: 0.0382
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0763 - mean_squared_error: 0.0763 - val_loss: 0.0435 - val_mean_squared_error: 0.0435
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0692 - mean_squared_error: 0.0692 - val_loss: 0.0499 - val_mean_squared_error: 0.0499
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0664 - mean_squared_error: 0.0664 - val_loss: 0.0586 - val_mean_squared_error: 0.0586
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0580 - mean_squared_error: 0.0580 - val_loss: 0.0706 - val_mean_squared_error: 0.0706
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0663 - mean_squared_error: 0.0663 - val_loss: 0.0850 - val_mean_squared_error: 0.0850
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0600 - mean_squared_error: 0.0600 - val_loss: 0.0967 - val_mean_squared_error: 0.0967
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0643 - mean_squared_error: 0.0643 - val_loss: 0.1116 - val_mean_squared_error: 0.1116
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0647 - mean_squared_error: 0.0647 - val_loss: 0.1269 - val_mean_squared_error: 0.1269
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0555 - mean_squared_error: 0.0555 - val_loss: 0.1514 - val_mean_squared_error: 0.1514
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0556 - mean_squared_error: 0.0556 - val_loss: 0.1735 - val_mean_squared_error: 0.1735
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0550 - mean_squared_error: 0.0550 - val_loss: 0.2026 - val_mean_squared_error: 0.2026
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0511 - mean_squared_error: 0.0511 - val_loss: 0.2410 - val_mean_squared_error: 0.2410
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0550 - mean_squared_error: 0.0550 - val_loss: 0.2776 - val_mean_squared_error: 0.2776
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0500 - mean_squared_error: 0.0500 - val_loss: 0.3309 - val_mean_squared_error: 0.3309
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0554 - mean_squared_error: 0.0554 - val_loss: 0.3921 - val_mean_squared_error: 0.3921
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0553 - mean_squared_error: 0.0553 - val_loss: 0.4749 - val_mean_squared_error: 0.4749
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0530 - mean_squared_error: 0.0530 - val_loss: 0.5612 - val_mean_squared_error: 0.5612
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0529 - mean_squared_error: 0.0529 - val_loss: 0.6770 - val_mean_squared_error: 0.6770
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0472 - mean_squared_error: 0.0472 - val_loss: 0.8018 - val_mean_squared_error: 0.8018
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0503 - mean_squared_error: 0.0503 - val_loss: 0.9256 - val_mean_squared_error: 0.9256
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 1.2540 - mean_squared_error: 1.2540 - val_loss: 0.1455 - val_mean_squared_error: 0.1455
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.4652 - mean_squared_error: 0.4652 - val_loss: 0.1293 - val_mean_squared_error: 0.1293
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.2728 - mean_squared_error: 0.2728 - val_loss: 0.1268 - val_mean_squared_error: 0.1268
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.2030 - mean_squared_error: 0.2030 - val_loss: 0.1299 - val_mean_squared_error: 0.1299
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1604 - mean_squared_error: 0.1604 - val_loss: 0.1414 - val_mean_squared_error: 0.1414
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1271 - mean_squared_error: 0.1271 - val_loss: 0.1581 - val_mean_squared_error: 0.1581
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1153 - mean_squared_error: 0.1153 - val_loss: 0.1798 - val_mean_squared_error: 0.1798
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1002 - mean_squared_error: 0.1002 - val_loss: 0.1944 - val_mean_squared_error: 0.1944
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0965 - mean_squared_error: 0.0965 - val_loss: 0.2233 - val_mean_squared_error: 0.2233
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0853 - mean_squared_error: 0.0853 - val_loss: 0.2442 - val_mean_squared_error: 0.2442
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0692 - mean_squared_error: 0.0692 - val_loss: 0.2567 - val_mean_squared_error: 0.2567
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0764 - mean_squared_error: 0.0764 - val_loss: 0.2726 - val_mean_squared_error: 0.2726
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0780 - mean_squared_error: 0.0780 - val_loss: 0.2857 - val_mean_squared_error: 0.2857
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0691 - mean_squared_error: 0.0691 - val_loss: 0.3113 - val_mean_squared_error: 0.3113
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0635 - mean_squared_error: 0.0635 - val_loss: 0.3187 - val_mean_squared_error: 0.3187
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0659 - mean_squared_error: 0.0659 - val_loss: 0.3298 - val_mean_squared_error: 0.3298
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0659 - mean_squared_error: 0.0659 - val_loss: 0.3353 - val_mean_squared_error: 0.3353
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0611 - mean_squared_error: 0.0611 - val_loss: 0.3267 - val_mean_squared_error: 0.3267
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0619 - mean_squared_error: 0.0619 - val_loss: 0.3292 - val_mean_squared_error: 0.3292
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0588 - mean_squared_error: 0.0588 - val_loss: 0.3324 - val_mean_squared_error: 0.3324
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0553 - mean_squared_error: 0.0553 - val_loss: 0.3331 - val_mean_squared_error: 0.3331
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0544 - mean_squared_error: 0.0544 - val_loss: 0.3478 - val_mean_squared_error: 0.3478
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0494 - mean_squared_error: 0.0494 - val_loss: 0.3652 - val_mean_squared_error: 0.3652
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0536 - mean_squared_error: 0.0536 - val_loss: 0.3777 - val_mean_squared_error: 0.3777
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0491 - mean_squared_error: 0.0491 - val_loss: 0.3799 - val_mean_squared_error: 0.3799
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0509 - mean_squared_error: 0.0509 - val_loss: 0.3999 - val_mean_squared_error: 0.3999
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0562 - mean_squared_error: 0.0562 - val_loss: 0.4333 - val_mean_squared_error: 0.4333
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0539 - mean_squared_error: 0.0539 - val_loss: 0.4522 - val_mean_squared_error: 0.4522
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0506 - mean_squared_error: 0.0506 - val_loss: 0.4838 - val_mean_squared_error: 0.4838
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0552 - mean_squared_error: 0.0552 - val_loss: 0.5273 - val_mean_squared_error: 0.5273
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 1.2762 - mean_squared_error: 1.2762 - val_loss: 0.1318 - val_mean_squared_error: 0.1318
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.4726 - mean_squared_error: 0.4726 - val_loss: 0.1049 - val_mean_squared_error: 0.1049
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.2853 - mean_squared_error: 0.2853 - val_loss: 0.0841 - val_mean_squared_error: 0.0841
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.2119 - mean_squared_error: 0.2119 - val_loss: 0.0665 - val_mean_squared_error: 0.0665
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1559 - mean_squared_error: 0.1559 - val_loss: 0.0528 - val_mean_squared_error: 0.0528
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1252 - mean_squared_error: 0.1252 - val_loss: 0.0428 - val_mean_squared_error: 0.0428
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0947 - mean_squared_error: 0.0947 - val_loss: 0.0349 - val_mean_squared_error: 0.0349
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0924 - mean_squared_error: 0.0924 - val_loss: 0.0329 - val_mean_squared_error: 0.0329
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0875 - mean_squared_error: 0.0875 - val_loss: 0.0334 - val_mean_squared_error: 0.0334
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0710 - mean_squared_error: 0.0710 - val_loss: 0.0311 - val_mean_squared_error: 0.0311
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0741 - mean_squared_error: 0.0741 - val_loss: 0.0297 - val_mean_squared_error: 0.0297
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0681 - mean_squared_error: 0.0681 - val_loss: 0.0288 - val_mean_squared_error: 0.0288
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0679 - mean_squared_error: 0.0679 - val_loss: 0.0311 - val_mean_squared_error: 0.0311
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0704 - mean_squared_error: 0.0704 - val_loss: 0.0309 - val_mean_squared_error: 0.0309
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0633 - mean_squared_error: 0.0633 - val_loss: 0.0329 - val_mean_squared_error: 0.0329
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0597 - mean_squared_error: 0.0597 - val_loss: 0.0365 - val_mean_squared_error: 0.0365
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0598 - mean_squared_error: 0.0598 - val_loss: 0.0350 - val_mean_squared_error: 0.0350
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0536 - mean_squared_error: 0.0536 - val_loss: 0.0411 - val_mean_squared_error: 0.0411
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0555 - mean_squared_error: 0.0555 - val_loss: 0.0481 - val_mean_squared_error: 0.0481
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0596 - mean_squared_error: 0.0596 - val_loss: 0.0469 - val_mean_squared_error: 0.0469
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0551 - mean_squared_error: 0.0551 - val_loss: 0.0481 - val_mean_squared_error: 0.0481
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0539 - mean_squared_error: 0.0539 - val_loss: 0.0519 - val_mean_squared_error: 0.0519
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0548 - mean_squared_error: 0.0548 - val_loss: 0.0546 - val_mean_squared_error: 0.0546
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0528 - mean_squared_error: 0.0528 - val_loss: 0.0560 - val_mean_squared_error: 0.0560
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0521 - mean_squared_error: 0.0521 - val_loss: 0.0644 - val_mean_squared_error: 0.0644
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0490 - mean_squared_error: 0.0490 - val_loss: 0.0767 - val_mean_squared_error: 0.0767
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0531 - mean_squared_error: 0.0531 - val_loss: 0.0827 - val_mean_squared_error: 0.0827
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0575 - mean_squared_error: 0.0575 - val_loss: 0.0979 - val_mean_squared_error: 0.0979
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0538 - mean_squared_error: 0.0538 - val_loss: 0.1114 - val_mean_squared_error: 0.1114
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0503 - mean_squared_error: 0.0503 - val_loss: 0.1315 - val_mean_squared_error: 0.1315
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.7635 - mean_squared_error: 0.7635 - val_loss: 0.1384 - val_mean_squared_error: 0.1384
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.3332 - mean_squared_error: 0.3332 - val_loss: 0.1131 - val_mean_squared_error: 0.1131
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.2577 - mean_squared_error: 0.2577 - val_loss: 0.0897 - val_mean_squared_error: 0.0897
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1798 - mean_squared_error: 0.1798 - val_loss: 0.0738 - val_mean_squared_error: 0.0738
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1285 - mean_squared_error: 0.1285 - val_loss: 0.0599 - val_mean_squared_error: 0.0599
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1046 - mean_squared_error: 0.1046 - val_loss: 0.0500 - val_mean_squared_error: 0.0500
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1049 - mean_squared_error: 0.1049 - val_loss: 0.0459 - val_mean_squared_error: 0.0459
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0915 - mean_squared_error: 0.0915 - val_loss: 0.0432 - val_mean_squared_error: 0.0432
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0834 - mean_squared_error: 0.0834 - val_loss: 0.0391 - val_mean_squared_error: 0.0391
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0836 - mean_squared_error: 0.0836 - val_loss: 0.0400 - val_mean_squared_error: 0.0400
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0785 - mean_squared_error: 0.0785 - val_loss: 0.0370 - val_mean_squared_error: 0.0370
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0719 - mean_squared_error: 0.0719 - val_loss: 0.0373 - val_mean_squared_error: 0.0373
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0692 - mean_squared_error: 0.0692 - val_loss: 0.0393 - val_mean_squared_error: 0.0393
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0646 - mean_squared_error: 0.0646 - val_loss: 0.0437 - val_mean_squared_error: 0.0437
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0592 - mean_squared_error: 0.0592 - val_loss: 0.0452 - val_mean_squared_error: 0.0452
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0649 - mean_squared_error: 0.0649 - val_loss: 0.0497 - val_mean_squared_error: 0.0497
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0571 - mean_squared_error: 0.0571 - val_loss: 0.0501 - val_mean_squared_error: 0.0501
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0544 - mean_squared_error: 0.0544 - val_loss: 0.0511 - val_mean_squared_error: 0.0511
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0635 - mean_squared_error: 0.0635 - val_loss: 0.0540 - val_mean_squared_error: 0.0540
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0554 - mean_squared_error: 0.0554 - val_loss: 0.0596 - val_mean_squared_error: 0.0596
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0550 - mean_squared_error: 0.0550 - val_loss: 0.0687 - val_mean_squared_error: 0.0687
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0605 - mean_squared_error: 0.0605 - val_loss: 0.0702 - val_mean_squared_error: 0.0702
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0521 - mean_squared_error: 0.0521 - val_loss: 0.0704 - val_mean_squared_error: 0.0704
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0563 - mean_squared_error: 0.0563 - val_loss: 0.0780 - val_mean_squared_error: 0.0780
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0501 - mean_squared_error: 0.0501 - val_loss: 0.0838 - val_mean_squared_error: 0.0838
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0522 - mean_squared_error: 0.0522 - val_loss: 0.0974 - val_mean_squared_error: 0.0974
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0536 - mean_squared_error: 0.0536 - val_loss: 0.1094 - val_mean_squared_error: 0.1094
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0515 - mean_squared_error: 0.0515 - val_loss: 0.1286 - val_mean_squared_error: 0.1286
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0561 - mean_squared_error: 0.0561 - val_loss: 0.1441 - val_mean_squared_error: 0.1441
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0563 - mean_squared_error: 0.0563 - val_loss: 0.1648 - val_mean_squared_error: 0.1648
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 1.2091 - mean_squared_error: 1.2091 - val_loss: 0.1338 - val_mean_squared_error: 0.1338
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.4830 - mean_squared_error: 0.4830 - val_loss: 0.1041 - val_mean_squared_error: 0.1041
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.3077 - mean_squared_error: 0.3077 - val_loss: 0.0804 - val_mean_squared_error: 0.0804
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.2252 - mean_squared_error: 0.2252 - val_loss: 0.0635 - val_mean_squared_error: 0.0635
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1678 - mean_squared_error: 0.1678 - val_loss: 0.0519 - val_mean_squared_error: 0.0519
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1282 - mean_squared_error: 0.1282 - val_loss: 0.0421 - val_mean_squared_error: 0.0421
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1036 - mean_squared_error: 0.1036 - val_loss: 0.0365 - val_mean_squared_error: 0.0365
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1061 - mean_squared_error: 0.1061 - val_loss: 0.0328 - val_mean_squared_error: 0.0328
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0957 - mean_squared_error: 0.0957 - val_loss: 0.0305 - val_mean_squared_error: 0.0305
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0744 - mean_squared_error: 0.0744 - val_loss: 0.0287 - val_mean_squared_error: 0.0287
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0710 - mean_squared_error: 0.0710 - val_loss: 0.0275 - val_mean_squared_error: 0.0275
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0686 - mean_squared_error: 0.0686 - val_loss: 0.0276 - val_mean_squared_error: 0.0276
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0617 - mean_squared_error: 0.0617 - val_loss: 0.0274 - val_mean_squared_error: 0.0274
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0610 - mean_squared_error: 0.0610 - val_loss: 0.0291 - val_mean_squared_error: 0.0291
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0625 - mean_squared_error: 0.0625 - val_loss: 0.0306 - val_mean_squared_error: 0.0306
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0601 - mean_squared_error: 0.0601 - val_loss: 0.0326 - val_mean_squared_error: 0.0326
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0570 - mean_squared_error: 0.0570 - val_loss: 0.0336 - val_mean_squared_error: 0.0336
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0555 - mean_squared_error: 0.0555 - val_loss: 0.0354 - val_mean_squared_error: 0.0354
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0684 - mean_squared_error: 0.0684 - val_loss: 0.0360 - val_mean_squared_error: 0.0360
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0617 - mean_squared_error: 0.0617 - val_loss: 0.0431 - val_mean_squared_error: 0.0431
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0563 - mean_squared_error: 0.0563 - val_loss: 0.0467 - val_mean_squared_error: 0.0467
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0556 - mean_squared_error: 0.0556 - val_loss: 0.0498 - val_mean_squared_error: 0.0498
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0612 - mean_squared_error: 0.0612 - val_loss: 0.0549 - val_mean_squared_error: 0.0549
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0548 - mean_squared_error: 0.0548 - val_loss: 0.0703 - val_mean_squared_error: 0.0703
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0551 - mean_squared_error: 0.0551 - val_loss: 0.0847 - val_mean_squared_error: 0.0847
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0586 - mean_squared_error: 0.0586 - val_loss: 0.0997 - val_mean_squared_error: 0.0997
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0525 - mean_squared_error: 0.0525 - val_loss: 0.1270 - val_mean_squared_error: 0.1270
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0523 - mean_squared_error: 0.0523 - val_loss: 0.1518 - val_mean_squared_error: 0.1518
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0505 - mean_squared_error: 0.0505 - val_loss: 0.1871 - val_mean_squared_error: 0.1871
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0524 - mean_squared_error: 0.0524 - val_loss: 0.2279 - val_mean_squared_error: 0.2279
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.8210 - mean_squared_error: 0.8210 - val_loss: 0.1219 - val_mean_squared_error: 0.1219
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.3155 - mean_squared_error: 0.3155 - val_loss: 0.0840 - val_mean_squared_error: 0.0840
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.2082 - mean_squared_error: 0.2082 - val_loss: 0.0601 - val_mean_squared_error: 0.0601
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1478 - mean_squared_error: 0.1478 - val_loss: 0.0421 - val_mean_squared_error: 0.0421
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1198 - mean_squared_error: 0.1198 - val_loss: 0.0364 - val_mean_squared_error: 0.0364
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1070 - mean_squared_error: 0.1070 - val_loss: 0.0380 - val_mean_squared_error: 0.0380
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0953 - mean_squared_error: 0.0953 - val_loss: 0.0424 - val_mean_squared_error: 0.0424
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0784 - mean_squared_error: 0.0784 - val_loss: 0.0501 - val_mean_squared_error: 0.0501
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0645 - mean_squared_error: 0.0645 - val_loss: 0.0595 - val_mean_squared_error: 0.0595
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0576 - mean_squared_error: 0.0576 - val_loss: 0.0729 - val_mean_squared_error: 0.0729
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0681 - mean_squared_error: 0.0681 - val_loss: 0.0820 - val_mean_squared_error: 0.0820
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0721 - mean_squared_error: 0.0721 - val_loss: 0.0891 - val_mean_squared_error: 0.0891
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0582 - mean_squared_error: 0.0582 - val_loss: 0.0991 - val_mean_squared_error: 0.0991
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0582 - mean_squared_error: 0.0582 - val_loss: 0.1112 - val_mean_squared_error: 0.1112
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0544 - mean_squared_error: 0.0544 - val_loss: 0.1104 - val_mean_squared_error: 0.1104
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0568 - mean_squared_error: 0.0568 - val_loss: 0.1146 - val_mean_squared_error: 0.1146
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0560 - mean_squared_error: 0.0560 - val_loss: 0.1193 - val_mean_squared_error: 0.1193
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0561 - mean_squared_error: 0.0561 - val_loss: 0.1267 - val_mean_squared_error: 0.1267
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0550 - mean_squared_error: 0.0550 - val_loss: 0.1285 - val_mean_squared_error: 0.1285
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0480 - mean_squared_error: 0.0480 - val_loss: 0.1326 - val_mean_squared_error: 0.1326
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0502 - mean_squared_error: 0.0502 - val_loss: 0.1364 - val_mean_squared_error: 0.1364
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0470 - mean_squared_error: 0.0470 - val_loss: 0.1352 - val_mean_squared_error: 0.1352
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0485 - mean_squared_error: 0.0485 - val_loss: 0.1401 - val_mean_squared_error: 0.1401
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0485 - mean_squared_error: 0.0485 - val_loss: 0.1389 - val_mean_squared_error: 0.1389
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0497 - mean_squared_error: 0.0497 - val_loss: 0.1488 - val_mean_squared_error: 0.1488
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0473 - mean_squared_error: 0.0473 - val_loss: 0.1310 - val_mean_squared_error: 0.1310
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0455 - mean_squared_error: 0.0455 - val_loss: 0.1552 - val_mean_squared_error: 0.1552
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0458 - mean_squared_error: 0.0458 - val_loss: 0.1807 - val_mean_squared_error: 0.1807
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0468 - mean_squared_error: 0.0468 - val_loss: 0.2071 - val_mean_squared_error: 0.2071
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0483 - mean_squared_error: 0.0483 - val_loss: 0.2924 - val_mean_squared_error: 0.2924
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 1.1025 - mean_squared_error: 1.1025 - val_loss: 0.1432 - val_mean_squared_error: 0.1432
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.4587 - mean_squared_error: 0.4587 - val_loss: 0.1199 - val_mean_squared_error: 0.1199
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.2759 - mean_squared_error: 0.2759 - val_loss: 0.0967 - val_mean_squared_error: 0.0967
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1913 - mean_squared_error: 0.1913 - val_loss: 0.0751 - val_mean_squared_error: 0.0751
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1580 - mean_squared_error: 0.1580 - val_loss: 0.0621 - val_mean_squared_error: 0.0621
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1188 - mean_squared_error: 0.1188 - val_loss: 0.0553 - val_mean_squared_error: 0.0553
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1042 - mean_squared_error: 0.1042 - val_loss: 0.0514 - val_mean_squared_error: 0.0514
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0977 - mean_squared_error: 0.0977 - val_loss: 0.0531 - val_mean_squared_error: 0.0531
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0706 - mean_squared_error: 0.0706 - val_loss: 0.0568 - val_mean_squared_error: 0.0568
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0845 - mean_squared_error: 0.0845 - val_loss: 0.0613 - val_mean_squared_error: 0.0613
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0645 - mean_squared_error: 0.0645 - val_loss: 0.0664 - val_mean_squared_error: 0.0664
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0645 - mean_squared_error: 0.0645 - val_loss: 0.0738 - val_mean_squared_error: 0.0738
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0615 - mean_squared_error: 0.0615 - val_loss: 0.0827 - val_mean_squared_error: 0.0827
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0532 - mean_squared_error: 0.0532 - val_loss: 0.0897 - val_mean_squared_error: 0.0897
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0572 - mean_squared_error: 0.0572 - val_loss: 0.1040 - val_mean_squared_error: 0.1040
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0565 - mean_squared_error: 0.0565 - val_loss: 0.1084 - val_mean_squared_error: 0.1084
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0579 - mean_squared_error: 0.0579 - val_loss: 0.1082 - val_mean_squared_error: 0.1082
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0623 - mean_squared_error: 0.0623 - val_loss: 0.1227 - val_mean_squared_error: 0.1227
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0532 - mean_squared_error: 0.0532 - val_loss: 0.1316 - val_mean_squared_error: 0.1316
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0484 - mean_squared_error: 0.0484 - val_loss: 0.1410 - val_mean_squared_error: 0.1410
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0496 - mean_squared_error: 0.0496 - val_loss: 0.1564 - val_mean_squared_error: 0.1564
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0497 - mean_squared_error: 0.0497 - val_loss: 0.1785 - val_mean_squared_error: 0.1785
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0488 - mean_squared_error: 0.0488 - val_loss: 0.1964 - val_mean_squared_error: 0.1964
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0443 - mean_squared_error: 0.0443 - val_loss: 0.2287 - val_mean_squared_error: 0.2287
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0470 - mean_squared_error: 0.0470 - val_loss: 0.2461 - val_mean_squared_error: 0.2461
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0487 - mean_squared_error: 0.0487 - val_loss: 0.2633 - val_mean_squared_error: 0.2633
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0494 - mean_squared_error: 0.0494 - val_loss: 0.2848 - val_mean_squared_error: 0.2848
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0500 - mean_squared_error: 0.0500 - val_loss: 0.3412 - val_mean_squared_error: 0.3412
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0464 - mean_squared_error: 0.0464 - val_loss: 0.4063 - val_mean_squared_error: 0.4063
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0520 - mean_squared_error: 0.0520 - val_loss: 0.4683 - val_mean_squared_error: 0.4683
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.6157 - mean_squared_error: 0.6157 - val_loss: 0.1391 - val_mean_squared_error: 0.1391
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.2645 - mean_squared_error: 0.2645 - val_loss: 0.1155 - val_mean_squared_error: 0.1155
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1804 - mean_squared_error: 0.1804 - val_loss: 0.0921 - val_mean_squared_error: 0.0921
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1471 - mean_squared_error: 0.1471 - val_loss: 0.0811 - val_mean_squared_error: 0.0811
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1085 - mean_squared_error: 0.1085 - val_loss: 0.0720 - val_mean_squared_error: 0.0720
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0906 - mean_squared_error: 0.0906 - val_loss: 0.0639 - val_mean_squared_error: 0.0639
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0737 - mean_squared_error: 0.0737 - val_loss: 0.0598 - val_mean_squared_error: 0.0598
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0714 - mean_squared_error: 0.0714 - val_loss: 0.0568 - val_mean_squared_error: 0.0568
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0651 - mean_squared_error: 0.0651 - val_loss: 0.0553 - val_mean_squared_error: 0.0553
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0584 - mean_squared_error: 0.0584 - val_loss: 0.0591 - val_mean_squared_error: 0.0591
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0529 - mean_squared_error: 0.0529 - val_loss: 0.0603 - val_mean_squared_error: 0.0603
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0541 - mean_squared_error: 0.0541 - val_loss: 0.0641 - val_mean_squared_error: 0.0641
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0544 - mean_squared_error: 0.0544 - val_loss: 0.0708 - val_mean_squared_error: 0.0708
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0473 - mean_squared_error: 0.0473 - val_loss: 0.0756 - val_mean_squared_error: 0.0756
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0526 - mean_squared_error: 0.0526 - val_loss: 0.0973 - val_mean_squared_error: 0.0973
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0455 - mean_squared_error: 0.0455 - val_loss: 0.1005 - val_mean_squared_error: 0.1005
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0440 - mean_squared_error: 0.0440 - val_loss: 0.1224 - val_mean_squared_error: 0.1224
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0468 - mean_squared_error: 0.0468 - val_loss: 0.1546 - val_mean_squared_error: 0.1546
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0489 - mean_squared_error: 0.0489 - val_loss: 0.1793 - val_mean_squared_error: 0.1793
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0467 - mean_squared_error: 0.0467 - val_loss: 0.2379 - val_mean_squared_error: 0.2379
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0444 - mean_squared_error: 0.0444 - val_loss: 0.2654 - val_mean_squared_error: 0.2654
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0489 - mean_squared_error: 0.0489 - val_loss: 0.3361 - val_mean_squared_error: 0.3361
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0442 - mean_squared_error: 0.0442 - val_loss: 0.4244 - val_mean_squared_error: 0.4244
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0439 - mean_squared_error: 0.0439 - val_loss: 0.4965 - val_mean_squared_error: 0.4965
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0481 - mean_squared_error: 0.0481 - val_loss: 0.6113 - val_mean_squared_error: 0.6113
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0438 - mean_squared_error: 0.0438 - val_loss: 0.7278 - val_mean_squared_error: 0.7278
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0451 - mean_squared_error: 0.0451 - val_loss: 0.9184 - val_mean_squared_error: 0.9184
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0428 - mean_squared_error: 0.0428 - val_loss: 1.0457 - val_mean_squared_error: 1.0457
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0421 - mean_squared_error: 0.0421 - val_loss: 1.3483 - val_mean_squared_error: 1.3483
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0470 - mean_squared_error: 0.0470 - val_loss: 1.5234 - val_mean_squared_error: 1.5234
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 1.6848 - mean_squared_error: 1.6848 - val_loss: 0.1327 - val_mean_squared_error: 0.1327
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.8281 - mean_squared_error: 0.8281 - val_loss: 0.1048 - val_mean_squared_error: 0.1048
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.5562 - mean_squared_error: 0.5562 - val_loss: 0.0833 - val_mean_squared_error: 0.0833
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.3242 - mean_squared_error: 0.3242 - val_loss: 0.0673 - val_mean_squared_error: 0.0673
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.2705 - mean_squared_error: 0.2705 - val_loss: 0.0550 - val_mean_squared_error: 0.0550
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.2226 - mean_squared_error: 0.2226 - val_loss: 0.0460 - val_mean_squared_error: 0.0460
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1683 - mean_squared_error: 0.1683 - val_loss: 0.0386 - val_mean_squared_error: 0.0386
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1303 - mean_squared_error: 0.1303 - val_loss: 0.0352 - val_mean_squared_error: 0.0352
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1299 - mean_squared_error: 0.1299 - val_loss: 0.0342 - val_mean_squared_error: 0.0342
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1327 - mean_squared_error: 0.1327 - val_loss: 0.0332 - val_mean_squared_error: 0.0332
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1031 - mean_squared_error: 0.1031 - val_loss: 0.0350 - val_mean_squared_error: 0.0350
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1014 - mean_squared_error: 0.1014 - val_loss: 0.0366 - val_mean_squared_error: 0.0366
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1031 - mean_squared_error: 0.1031 - val_loss: 0.0385 - val_mean_squared_error: 0.0385
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0810 - mean_squared_error: 0.0810 - val_loss: 0.0403 - val_mean_squared_error: 0.0403
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0778 - mean_squared_error: 0.0778 - val_loss: 0.0400 - val_mean_squared_error: 0.0400
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0766 - mean_squared_error: 0.0766 - val_loss: 0.0384 - val_mean_squared_error: 0.0384
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0733 - mean_squared_error: 0.0733 - val_loss: 0.0404 - val_mean_squared_error: 0.0404
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0759 - mean_squared_error: 0.0759 - val_loss: 0.0419 - val_mean_squared_error: 0.0419
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0749 - mean_squared_error: 0.0749 - val_loss: 0.0419 - val_mean_squared_error: 0.0419
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0656 - mean_squared_error: 0.0656 - val_loss: 0.0397 - val_mean_squared_error: 0.0397
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0638 - mean_squared_error: 0.0638 - val_loss: 0.0400 - val_mean_squared_error: 0.0400
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0645 - mean_squared_error: 0.0645 - val_loss: 0.0430 - val_mean_squared_error: 0.0430
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0619 - mean_squared_error: 0.0619 - val_loss: 0.0458 - val_mean_squared_error: 0.0458
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0629 - mean_squared_error: 0.0629 - val_loss: 0.0493 - val_mean_squared_error: 0.0493
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0582 - mean_squared_error: 0.0582 - val_loss: 0.0585 - val_mean_squared_error: 0.0585
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0647 - mean_squared_error: 0.0647 - val_loss: 0.0632 - val_mean_squared_error: 0.0632
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0539 - mean_squared_error: 0.0539 - val_loss: 0.0734 - val_mean_squared_error: 0.0734
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0512 - mean_squared_error: 0.0512 - val_loss: 0.0863 - val_mean_squared_error: 0.0863
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0603 - mean_squared_error: 0.0603 - val_loss: 0.1017 - val_mean_squared_error: 0.1017
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0522 - mean_squared_error: 0.0522 - val_loss: 0.1262 - val_mean_squared_error: 0.1262
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 1.2409 - mean_squared_error: 1.2409 - val_loss: 0.1352 - val_mean_squared_error: 0.1352
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.3637 - mean_squared_error: 0.3637 - val_loss: 0.1063 - val_mean_squared_error: 0.1063
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.2289 - mean_squared_error: 0.2289 - val_loss: 0.0821 - val_mean_squared_error: 0.0821
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1602 - mean_squared_error: 0.1602 - val_loss: 0.0615 - val_mean_squared_error: 0.0615
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1287 - mean_squared_error: 0.1287 - val_loss: 0.0473 - val_mean_squared_error: 0.0473
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0967 - mean_squared_error: 0.0967 - val_loss: 0.0378 - val_mean_squared_error: 0.0378
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0828 - mean_squared_error: 0.0828 - val_loss: 0.0306 - val_mean_squared_error: 0.0306
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0718 - mean_squared_error: 0.0718 - val_loss: 0.0251 - val_mean_squared_error: 0.0251
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0680 - mean_squared_error: 0.0680 - val_loss: 0.0227 - val_mean_squared_error: 0.0227
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0653 - mean_squared_error: 0.0653 - val_loss: 0.0211 - val_mean_squared_error: 0.0211
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0591 - mean_squared_error: 0.0591 - val_loss: 0.0211 - val_mean_squared_error: 0.0211
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0580 - mean_squared_error: 0.0580 - val_loss: 0.0221 - val_mean_squared_error: 0.0221
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0528 - mean_squared_error: 0.0528 - val_loss: 0.0238 - val_mean_squared_error: 0.0238
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0546 - mean_squared_error: 0.0546 - val_loss: 0.0235 - val_mean_squared_error: 0.0235
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0516 - mean_squared_error: 0.0516 - val_loss: 0.0262 - val_mean_squared_error: 0.0262
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0547 - mean_squared_error: 0.0547 - val_loss: 0.0288 - val_mean_squared_error: 0.0288
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0491 - mean_squared_error: 0.0491 - val_loss: 0.0315 - val_mean_squared_error: 0.0315
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0491 - mean_squared_error: 0.0491 - val_loss: 0.0358 - val_mean_squared_error: 0.0358
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0509 - mean_squared_error: 0.0509 - val_loss: 0.0404 - val_mean_squared_error: 0.0404
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0512 - mean_squared_error: 0.0512 - val_loss: 0.0402 - val_mean_squared_error: 0.0402
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0558 - mean_squared_error: 0.0558 - val_loss: 0.0374 - val_mean_squared_error: 0.0374
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0514 - mean_squared_error: 0.0514 - val_loss: 0.0411 - val_mean_squared_error: 0.0411
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0508 - mean_squared_error: 0.0508 - val_loss: 0.0435 - val_mean_squared_error: 0.0435
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0450 - mean_squared_error: 0.0450 - val_loss: 0.0450 - val_mean_squared_error: 0.0450
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0520 - mean_squared_error: 0.0520 - val_loss: 0.0580 - val_mean_squared_error: 0.0580
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0471 - mean_squared_error: 0.0471 - val_loss: 0.0720 - val_mean_squared_error: 0.0720
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0456 - mean_squared_error: 0.0456 - val_loss: 0.0903 - val_mean_squared_error: 0.0903
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0484 - mean_squared_error: 0.0484 - val_loss: 0.1232 - val_mean_squared_error: 0.1232
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0432 - mean_squared_error: 0.0432 - val_loss: 0.1386 - val_mean_squared_error: 0.1386
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0460 - mean_squared_error: 0.0460 - val_loss: 0.1703 - val_mean_squared_error: 0.1703
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 1.4072 - mean_squared_error: 1.4072 - val_loss: 0.1350 - val_mean_squared_error: 0.1350
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.4770 - mean_squared_error: 0.4770 - val_loss: 0.1146 - val_mean_squared_error: 0.1146
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.2905 - mean_squared_error: 0.2905 - val_loss: 0.1009 - val_mean_squared_error: 0.1009
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1979 - mean_squared_error: 0.1979 - val_loss: 0.0911 - val_mean_squared_error: 0.0911
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1614 - mean_squared_error: 0.1614 - val_loss: 0.0838 - val_mean_squared_error: 0.0838
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1421 - mean_squared_error: 0.1421 - val_loss: 0.0755 - val_mean_squared_error: 0.0755
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1045 - mean_squared_error: 0.1045 - val_loss: 0.0683 - val_mean_squared_error: 0.0683
# Train on 320 samples, validate on 7776 samples
# ...
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0707 - mean_squared_error: 0.0707 - val_loss: 0.0638 - val_mean_squared_error: 0.0638
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0647 - mean_squared_error: 0.0647 - val_loss: 0.0673 - val_mean_squared_error: 0.0673
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0617 - mean_squared_error: 0.0617 - val_loss: 0.0706 - val_mean_squared_error: 0.0706
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0693 - mean_squared_error: 0.0693 - val_loss: 0.0776 - val_mean_squared_error: 0.0776
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0649 - mean_squared_error: 0.0649 - val_loss: 0.0860 - val_mean_squared_error: 0.0860
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0561 - mean_squared_error: 0.0561 - val_loss: 0.1042 - val_mean_squared_error: 0.1042
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0593 - mean_squared_error: 0.0593 - val_loss: 0.1265 - val_mean_squared_error: 0.1265
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0631 - mean_squared_error: 0.0631 - val_loss: 0.1572 - val_mean_squared_error: 0.1572
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0497 - mean_squared_error: 0.0497 - val_loss: 0.1983 - val_mean_squared_error: 0.1983
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0553 - mean_squared_error: 0.0553 - val_loss: 0.2570 - val_mean_squared_error: 0.2570
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0556 - mean_squared_error: 0.0556 - val_loss: 0.3309 - val_mean_squared_error: 0.3309
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0517 - mean_squared_error: 0.0517 - val_loss: 0.4308 - val_mean_squared_error: 0.4308
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0466 - mean_squared_error: 0.0466 - val_loss: 0.5548 - val_mean_squared_error: 0.5548
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0509 - mean_squared_error: 0.0509 - val_loss: 0.7568 - val_mean_squared_error: 0.7568
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0485 - mean_squared_error: 0.0485 - val_loss: 1.0224 - val_mean_squared_error: 1.0224
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0508 - mean_squared_error: 0.0508 - val_loss: 1.3416 - val_mean_squared_error: 1.3416
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0500 - mean_squared_error: 0.0500 - val_loss: 1.7497 - val_mean_squared_error: 1.7497
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0524 - mean_squared_error: 0.0524 - val_loss: 2.3725 - val_mean_squared_error: 2.3725
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0500 - mean_squared_error: 0.0500 - val_loss: 3.2128 - val_mean_squared_error: 3.2128
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0510 - mean_squared_error: 0.0510 - val_loss: 4.1424 - val_mean_squared_error: 4.1424
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.9393 - mean_squared_error: 0.9393 - val_loss: 0.1178 - val_mean_squared_error: 0.1178
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.4042 - mean_squared_error: 0.4042 - val_loss: 0.0807 - val_mean_squared_error: 0.0807
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.2515 - mean_squared_error: 0.2515 - val_loss: 0.0573 - val_mean_squared_error: 0.0573
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1904 - mean_squared_error: 0.1904 - val_loss: 0.0443 - val_mean_squared_error: 0.0443
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1727 - mean_squared_error: 0.1727 - val_loss: 0.0392 - val_mean_squared_error: 0.0392
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1262 - mean_squared_error: 0.1262 - val_loss: 0.0418 - val_mean_squared_error: 0.0418
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1164 - mean_squared_error: 0.1164 - val_loss: 0.0503 - val_mean_squared_error: 0.0503
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0905 - mean_squared_error: 0.0905 - val_loss: 0.0643 - val_mean_squared_error: 0.0643
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0844 - mean_squared_error: 0.0844 - val_loss: 0.0794 - val_mean_squared_error: 0.0794
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0702 - mean_squared_error: 0.0702 - val_loss: 0.0957 - val_mean_squared_error: 0.0957
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0656 - mean_squared_error: 0.0656 - val_loss: 0.1090 - val_mean_squared_error: 0.1090
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0711 - mean_squared_error: 0.0711 - val_loss: 0.1251 - val_mean_squared_error: 0.1251
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0813 - mean_squared_error: 0.0813 - val_loss: 0.1382 - val_mean_squared_error: 0.1382
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0729 - mean_squared_error: 0.0729 - val_loss: 0.1564 - val_mean_squared_error: 0.1564
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0615 - mean_squared_error: 0.0615 - val_loss: 0.1666 - val_mean_squared_error: 0.1666
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0574 - mean_squared_error: 0.0574 - val_loss: 0.1743 - val_mean_squared_error: 0.1743
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0556 - mean_squared_error: 0.0556 - val_loss: 0.1867 - val_mean_squared_error: 0.1867
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0564 - mean_squared_error: 0.0564 - val_loss: 0.1946 - val_mean_squared_error: 0.1946
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0541 - mean_squared_error: 0.0541 - val_loss: 0.1982 - val_mean_squared_error: 0.1982
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0592 - mean_squared_error: 0.0592 - val_loss: 0.1968 - val_mean_squared_error: 0.1968
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0505 - mean_squared_error: 0.0505 - val_loss: 0.1916 - val_mean_squared_error: 0.1916
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0528 - mean_squared_error: 0.0528 - val_loss: 0.1837 - val_mean_squared_error: 0.1837
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0498 - mean_squared_error: 0.0498 - val_loss: 0.1733 - val_mean_squared_error: 0.1733
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0504 - mean_squared_error: 0.0504 - val_loss: 0.1716 - val_mean_squared_error: 0.1716
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0500 - mean_squared_error: 0.0500 - val_loss: 0.1599 - val_mean_squared_error: 0.1599
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0552 - mean_squared_error: 0.0552 - val_loss: 0.1546 - val_mean_squared_error: 0.1546
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0526 - mean_squared_error: 0.0526 - val_loss: 0.1614 - val_mean_squared_error: 0.1614
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0514 - mean_squared_error: 0.0514 - val_loss: 0.1402 - val_mean_squared_error: 0.1402
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0513 - mean_squared_error: 0.0513 - val_loss: 0.1479 - val_mean_squared_error: 0.1479
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0479 - mean_squared_error: 0.0479 - val_loss: 0.1746 - val_mean_squared_error: 0.1746
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 1.0967 - mean_squared_error: 1.0967 - val_loss: 0.1241 - val_mean_squared_error: 0.1241
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.4150 - mean_squared_error: 0.4150 - val_loss: 0.0891 - val_mean_squared_error: 0.0891
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.2253 - mean_squared_error: 0.2253 - val_loss: 0.0648 - val_mean_squared_error: 0.0648
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1691 - mean_squared_error: 0.1691 - val_loss: 0.0499 - val_mean_squared_error: 0.0499
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1360 - mean_squared_error: 0.1360 - val_loss: 0.0411 - val_mean_squared_error: 0.0411
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1081 - mean_squared_error: 0.1081 - val_loss: 0.0362 - val_mean_squared_error: 0.0362
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1030 - mean_squared_error: 0.1030 - val_loss: 0.0351 - val_mean_squared_error: 0.0351
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0810 - mean_squared_error: 0.0810 - val_loss: 0.0386 - val_mean_squared_error: 0.0386
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0752 - mean_squared_error: 0.0752 - val_loss: 0.0448 - val_mean_squared_error: 0.0448
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0735 - mean_squared_error: 0.0735 - val_loss: 0.0514 - val_mean_squared_error: 0.0514
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0689 - mean_squared_error: 0.0689 - val_loss: 0.0593 - val_mean_squared_error: 0.0593
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0649 - mean_squared_error: 0.0649 - val_loss: 0.0676 - val_mean_squared_error: 0.0676
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0655 - mean_squared_error: 0.0655 - val_loss: 0.0782 - val_mean_squared_error: 0.0782
# Train on 320 samples, validate on 7776 samples
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0503 - mean_squared_error: 0.0503 - val_loss: 0.4320 - val_mean_squared_error: 0.4320
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0570 - mean_squared_error: 0.0570 - val_loss: 0.5036 - val_mean_squared_error: 0.5036
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0502 - mean_squared_error: 0.0502 - val_loss: 0.6167 - val_mean_squared_error: 0.6167
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0512 - mean_squared_error: 0.0512 - val_loss: 0.8484 - val_mean_squared_error: 0.8484
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0480 - mean_squared_error: 0.0480 - val_loss: 0.9883 - val_mean_squared_error: 0.9883
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0477 - mean_squared_error: 0.0477 - val_loss: 1.2287 - val_mean_squared_error: 1.2287
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0576 - mean_squared_error: 0.0576 - val_loss: 1.5732 - val_mean_squared_error: 1.5732
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0459 - mean_squared_error: 0.0459 - val_loss: 2.4025 - val_mean_squared_error: 2.4025
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0514 - mean_squared_error: 0.0514 - val_loss: 2.8709 - val_mean_squared_error: 2.8709
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.9323 - mean_squared_error: 0.9323 - val_loss: 0.1281 - val_mean_squared_error: 0.1281
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.2830 - mean_squared_error: 0.2830 - val_loss: 0.1094 - val_mean_squared_error: 0.1094
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.2121 - mean_squared_error: 0.2121 - val_loss: 0.1024 - val_mean_squared_error: 0.1024
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1582 - mean_squared_error: 0.1582 - val_loss: 0.1081 - val_mean_squared_error: 0.1081
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1270 - mean_squared_error: 0.1270 - val_loss: 0.1231 - val_mean_squared_error: 0.1231
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0978 - mean_squared_error: 0.0978 - val_loss: 0.1492 - val_mean_squared_error: 0.1492
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0801 - mean_squared_error: 0.0801 - val_loss: 0.1803 - val_mean_squared_error: 0.1803
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0659 - mean_squared_error: 0.0659 - val_loss: 0.2223 - val_mean_squared_error: 0.2223
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0597 - mean_squared_error: 0.0597 - val_loss: 0.2607 - val_mean_squared_error: 0.2607
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0543 - mean_squared_error: 0.0543 - val_loss: 0.2915 - val_mean_squared_error: 0.2915
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0541 - mean_squared_error: 0.0541 - val_loss: 0.3389 - val_mean_squared_error: 0.3389
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0525 - mean_squared_error: 0.0525 - val_loss: 0.3778 - val_mean_squared_error: 0.3778
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0490 - mean_squared_error: 0.0490 - val_loss: 0.4237 - val_mean_squared_error: 0.4237
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0507 - mean_squared_error: 0.0507 - val_loss: 0.4573 - val_mean_squared_error: 0.4573
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0461 - mean_squared_error: 0.0461 - val_loss: 0.5019 - val_mean_squared_error: 0.5019
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0530 - mean_squared_error: 0.0530 - val_loss: 0.5523 - val_mean_squared_error: 0.5523
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0449 - mean_squared_error: 0.0449 - val_loss: 0.5807 - val_mean_squared_error: 0.5807
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0425 - mean_squared_error: 0.0425 - val_loss: 0.6374 - val_mean_squared_error: 0.6374
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0431 - mean_squared_error: 0.0431 - val_loss: 0.6788 - val_mean_squared_error: 0.6788
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0459 - mean_squared_error: 0.0459 - val_loss: 0.7142 - val_mean_squared_error: 0.7142
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.7596 - val_mean_squared_error: 0.7596
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0483 - mean_squared_error: 0.0483 - val_loss: 0.8175 - val_mean_squared_error: 0.8175
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0456 - mean_squared_error: 0.0456 - val_loss: 0.8384 - val_mean_squared_error: 0.8384
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0425 - mean_squared_error: 0.0425 - val_loss: 0.8956 - val_mean_squared_error: 0.8956
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0446 - mean_squared_error: 0.0446 - val_loss: 0.9237 - val_mean_squared_error: 0.9237
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0410 - mean_squared_error: 0.0410 - val_loss: 1.0137 - val_mean_squared_error: 1.0137
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0429 - mean_squared_error: 0.0429 - val_loss: 1.0430 - val_mean_squared_error: 1.0430
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0405 - mean_squared_error: 0.0405 - val_loss: 1.1149 - val_mean_squared_error: 1.1149
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0364 - mean_squared_error: 0.0364 - val_loss: 1.1589 - val_mean_squared_error: 1.1589
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0399 - mean_squared_error: 0.0399 - val_loss: 1.2298 - val_mean_squared_error: 1.2298

# %%
record
# Out:
# [(4,
#   3,
#   8,
#   [0.047170025482773784],
#   [0.0372450783496163],
#   (array([8]), array([0]))),
#  (4,
#   3,
#   16,
#   [0.04907047338783741],
#   [0.12679117507159465],
#   (array([2]), array([0]))),
#  (4,
#   4,
#   8,
#   [0.04896475598216057],
#   [0.028780571794436303],
#   (array([11]), array([0]))),
#  (4,
#   4,
#   16,
#   [0.05008333809673786],
#   [0.03699441645830992],
#   (array([10]), array([0]))),
#  (4,
#   5,
#   8,
#   [0.05047358311712742],
#   [0.027383882606041774],
#   (array([12]), array([0]))),
#  (4,
#   5,
#   16,
#   [0.04549816995859146],
#   [0.03641178824559406],
#   (array([4]), array([0]))),
#  (8,
#   3,
#   8,
#   [0.04426582045853138],
#   [0.05143693928058746],
#   (array([6]), array([0]))),
#  (8,
#   3,
#   16,
#   [0.042094594426453115],
#   [0.05528342397308644],
#   (array([8]), array([0]))),
#  (8,
#   4,
#   8,
#   [0.05116790011525154],
#   [0.03318405470239773],
#   (array([9]), array([0]))),
#  (8,
#   4,
#   16,
#   [0.04322846084833145],
#   [0.021089329495412822],
#   (array([10]), array([0]))),
#  (8,
#   5,
#   8,
#   [0.0465620893985033],
#   [0.062401089909268015],
#   (array([9]), array([0]))),
#  (8,
#   5,
#   16,
#   [0.04792216494679451],
#   [0.0392039757175946],
#   (array([4]), array([0]))),
#  (16,
#   3,
#   8,
#   [0.04906433001160622],
#   [0.03505314333908597],
#   (array([6]), array([0]))),
#  (16,
#   3,
#   16,
#   [0.04067770801484585],
#   [0.1223938999843205],
#   (array([2]), array([0]))),
#  (16,
#   4,
#   8,
#   [0.04608825221657753],
#   [0.02473553376647916],
#   (array([11]), array([0]))),
#  (16,
#   4,
#   16,
#   [0.03909857869148255],
#   [0.05064121253573845],
#   (array([7]), array([0]))),
#  (16,
#   5,
#   8,
#   [0.04590092860162258],
#   [0.03302093674984488],
#   (array([5]), array([0]))),
#  (16,
#   5,
#   16,
#   [0.036383474990725514],
#   [0.10244837489147736],
#   (array([2]), array([0])))]

# %% [markdown]
# ## best model being - kernel size 8, layer 4, nchan_out 16, batchsize 32, steps_per_epoch 10 - save model as chkpt
#
# train on different J,Q, order and save performance

# %%
model=create_model(J,Q,order,input_x,input_y,k_size=8,layer_size=4,nchan_out=16)
val_loss = []
for epoch in range(30):
    np.random.shuffle(idx)
    Sy_temp = Sy_train[idx[:m],:,:]
    y_temp = y_train_normalized[idx[:m],:]
    
    hist = model.fit(Sy_temp,
                y_temp,
                epochs=1,
                verbose=2,
                batch_size=32,
                validation_data = (Sy_val,y_val_normalized),
                callbacks = callbacks
                use_multiprocessing=True)
    
    val_loss.append(hist.history['val_loss'])
    if epoch >0 and hist.history['val_loss']>val_loss[-2]:
        model.save(model_filepath)
        np.savetxt(log_filepath, np.array(hist.history[]), delimiter=",")
# Out:
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 1.1009 - mean_squared_error: 1.1009 - val_loss: 0.1425 - val_mean_squared_error: 0.1425
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.3401 - mean_squared_error: 0.3401 - val_loss: 0.1213 - val_mean_squared_error: 0.1213
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.2241 - mean_squared_error: 0.2241 - val_loss: 0.1056 - val_mean_squared_error: 0.1056
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1710 - mean_squared_error: 0.1710 - val_loss: 0.0940 - val_mean_squared_error: 0.0940
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1508 - mean_squared_error: 0.1508 - val_loss: 0.0839 - val_mean_squared_error: 0.0839
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1208 - mean_squared_error: 0.1208 - val_loss: 0.0751 - val_mean_squared_error: 0.0751
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.1063 - mean_squared_error: 0.1063 - val_loss: 0.0695 - val_mean_squared_error: 0.0695
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0997 - mean_squared_error: 0.0997 - val_loss: 0.0649 - val_mean_squared_error: 0.0649
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0886 - mean_squared_error: 0.0886 - val_loss: 0.0644 - val_mean_squared_error: 0.0644
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0840 - mean_squared_error: 0.0840 - val_loss: 0.0632 - val_mean_squared_error: 0.0632
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0647 - mean_squared_error: 0.0647 - val_loss: 0.0621 - val_mean_squared_error: 0.0621
# Train on 320 samples, validate on 7776 samples
# 320/320 - 1s - loss: 0.0746 - mean_squared_error: 0.0746 - val_loss: 0.0641 - val_mean_squared_error: 0.0641
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-b5a5466e091a> in <module>
#      17     if epoch >0 and hist.history['val_loss']>val_loss[-2]:
#      18         model.save(model_filepath)
# ---> 19         np.savetxt(log_filepath, np.array(hist.history), delimiter=",")
#      20
#
# <__array_function__ internals> in savetxt(*args, **kwargs)
#
# ~/miniconda3/envs/drum-1.15/lib/python3.7/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1393         if X.ndim == 0 or X.ndim > 2:
#    1394             raise ValueError(
# -> 1395                 "Expected 1D or 2D array, got %dD array instead" % X.ndim)
#    1396         elif X.ndim == 1:
#    1397             # Common case -- 1d array of numbers
#
# ValueError: Expected 1D or 2D array, got 0D array instead

# %%
#dict = {'Python' : '.py', 'C++' : '.cpp', 'Java' : '.java'}
f = open(log_filepath,"w")
f.write( str(hist.history) )
f.close()

# %% [markdown]
# ## ugh in order to enable save checkpoint i have to use generator

# %%
class DataGenerator(tensorflow.keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, Sy_train, y_train, batch_size=32, shuffle=True):
        'Initialization'
        self.batch_size = batch_size
        self.Sy_train = Sy_train
        self.y_train = y_train
        self.shuffle = shuffle
        #self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(self.Sy_train.shape[0] / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = np.arange(0,self.Sy_train.shape[0],1)
        np.random.shuffle(indexes)
        
        # Generate data
        X, y = self.__data_generation(indexes[:self.batch_size])

        return X, y

#    def on_epoch_end(self):
#        'Updates indexes after each epoch'
#        self.indexes = np.arange(len(self.list_IDs))
#        if self.shuffle == True:
#            np.random.shuffle(self.indexes)

    def __data_generation(self, list_IDs_temp):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = self.Sy_train[list_IDs_temp,:,:]
        y = self.y_train[list_IDs_temp,:]

        return X, y

# %%
params = {'batch_size': 64,
          'shuffle': True}
training_generator = DataGenerator(Sy_train, y_train_normalized, **params)

# %%
output_dir = "../output/"

if not os.path.exists(output_dir):
    os.makedirs(output_dir)
model_filepath = os.path.join(output_dir, "cp_best.ckpt")
log_filepath = os.path.join(output_dir, 'train_log.csv')

callbacks = []
callbacks.append(EarlyStopping(monitor='val_loss',patience=0,verbose=1))
callbacks.append(ModelCheckpoint(model_filepath, save_best_only=True))
callbacks.append(CSVLogger(log_filepath))

# %%
model=create_model(J,Q,order,input_x,input_y,k_size=8,layer_size=4,nchan_out=16)
model.fit(training_generator,
          steps_per_epoch=10,
          verbose=2,
          callbacks = callbacks,
          epochs = 10, 
         validation_data=(Sy_val,y_val_normalized),
          use_multiprocessing=True)
# Out:
# Epoch 1/10
# Epoch 1/10
# 7776/10 - 1s - loss: 0.1792 - mean_squared_error: 0.1266
# 10/10 - 3s - loss: 1.0260 - mean_squared_error: 1.0260 - val_loss: 0.1270 - val_mean_squared_error: 0.1266
# Epoch 2/10
# Epoch 1/10
# 7776/10 - 1s - loss: 0.1347 - mean_squared_error: 0.0902
# 10/10 - 1s - loss: 0.3806 - mean_squared_error: 0.3806 - val_loss: 0.0906 - val_mean_squared_error: 0.0902
# Epoch 3/10
# Epoch 1/10
# 7776/10 - 1s - loss: 0.1018 - mean_squared_error: 0.0646
# 10/10 - 1s - loss: 0.2411 - mean_squared_error: 0.2411 - val_loss: 0.0649 - val_mean_squared_error: 0.0646
# Epoch 4/10
# Epoch 1/10
# 7776/10 - 1s - loss: 0.0762 - mean_squared_error: 0.0461
# 10/10 - 1s - loss: 0.1723 - mean_squared_error: 0.1723 - val_loss: 0.0464 - val_mean_squared_error: 0.0461
# Epoch 5/10
# Epoch 1/10
# 7776/10 - 1s - loss: 0.0589 - mean_squared_error: 0.0347
# 10/10 - 1s - loss: 0.1330 - mean_squared_error: 0.1330 - val_loss: 0.0349 - val_mean_squared_error: 0.0347
# Epoch 6/10
# Epoch 1/10
# 7776/10 - 1s - loss: 0.0464 - mean_squared_error: 0.0285
# 10/10 - 1s - loss: 0.1072 - mean_squared_error: 0.1072 - val_loss: 0.0286 - val_mean_squared_error: 0.0285
# Epoch 7/10
# Epoch 1/10
# 7776/10 - 1s - loss: 0.0400 - mean_squared_error: 0.0269
# 10/10 - 1s - loss: 0.0918 - mean_squared_error: 0.0918 - val_loss: 0.0270 - val_mean_squared_error: 0.0269
# Epoch 8/10
# Epoch 1/10
# 7776/10 - 1s - loss: 0.0375 - mean_squared_error: 0.0285
# 10/10 - 1s - loss: 0.0801 - mean_squared_error: 0.0801 - val_loss: 0.0286 - val_mean_squared_error: 0.0285
# Epoch 00008: early stopping

# %% [markdown]
# save checkpoint

# %%
model2=create_model(J,Q,order,input_x,input_y,k_size=8,layer_size=4,nchan_out=16)
model2.load_weights(model_filepath)

# %%
example = df_test.values[0,:]
name = str(example[0])+"_sound.wav"
params = example[1:]
y,fs = librosa.load("/scratch/hh2263/drum_data/test/"+name)

# %%
params
# Out:
# array([12353.875421473127, 0.1515511077684384, 0.0015630271691019885,
#        0.047278615741408986, 0.3968901393586017, 'test'], dtype=object)

# %%
scattering = Scattering1D(J=J, shape=(2**15,), Q=Q, max_order=order)
Sx = np.array(scattering(torch.Tensor(y)).T)

# %%
Sx.shape
# Out:
# (128, 43)

# %%
predicted = model2.predict(Sx.reshape((1,128,43)))

# %%
scaler.inverse_transform(predicted)
# Out:
# array([[6.1175972e+03, 1.2335956e-01, 3.6207625e-01, 2.7610660e-01,
#         5.6290185e-01]], dtype=float32)
